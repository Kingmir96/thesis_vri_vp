# %% [markdown]
# # Simulation Study for Noise Filtering
#
# This is the v0 for the simulation study on the sparse jump model comparison with HMM, to show that SJM is able to filter away noisy data by using the weighting in the algorithm.

# %%
# Load packages
import numpy as np
import pandas as pd
from hmmlearn import hmm
from sklearn.metrics import balanced_accuracy_score, confusion_matrix
from scipy.optimize import linear_sum_assignment
from jumpmodels.sparse_jump import SparseJumpModel    # Sparse JM class
from jumpmodels.jump import JumpModel   
from scipy import stats
from joblib import Parallel, delayed
import multiprocessing
from scipy.stats import wilcoxon

# %% [markdown]
# ## 1. Data Simulation & Utility Functions
# def simulate_data(T, P, mu, random_state=None): """ Simulate data from a 2-state Gaussian HMM with correlation 0.1 between the features

# %%
def simulate_data(T, P, mu, random_state=None):
    """
    Simulate data from a 2-state Gaussian HMM with correlated noise for features beyond
    the first 15 informative features.
    """
    rng = np.random.default_rng(random_state)
    
    # Transition matrix for 2 states
    transmat = np.array([[0.9980, 0.0020],
                         [0.0114, 0.9886]])
    
    # Compute stationary distribution
    eigvals, eigvecs = np.linalg.eig(transmat.T)
    stat = np.real(eigvecs[:, np.isclose(eigvals, 1)])
    stat = stat[:, 0]
    stat = stat / np.sum(stat)
    
    # Generate state sequence
    states = np.zeros(T, dtype=int)
    states[0] = rng.choice(np.arange(2), p=stat)
    for t in range(1, T):
        states[t] = rng.choice(np.arange(2), p=transmat[states[t-1]])
    
    # Define means for each state: first 15 features are informative
    means = np.zeros((2, P))
    if P >= 15:
        means[0, :15] = -mu
        means[1, :15] = mu
    else:
        means[0, :P] = -mu
        means[1, :P] = mu
    
    # Prepare correlated noise for features beyond the first 15
    informative = 15
    if P > informative:
        num_noise = P - informative
        sigma = np.full((num_noise, num_noise), 0.185)
        np.fill_diagonal(sigma, 1.0)
        C = np.linalg.cholesky(sigma)
    else:
        C = None
    
    # Generate observations
    X = np.zeros((T, P))
    for t in range(T):
        # Informative features
        n_inf = min(P, informative)
        X[t, :n_inf] = rng.normal(loc=means[states[t], :n_inf], scale=1.0, size=n_inf)
        # Noise features: correlated noise if P > informative
        if P > informative:
            noise_indep = rng.normal(loc=0.0, scale=1.0, size=P - informative)
            X[t, informative:] = C @ noise_indep
    
    return X, states

# %% [markdown]
# ## 2.Aligning Predicted Labels With True Labels using the Hungarian Algorithm

# %%
def align_labels(true_labels, pred_labels):
    """
    Align predicted labels with true labels using the Hungarian algorithm.
    """
    D = confusion_matrix(true_labels, pred_labels)
    row_ind, col_ind = linear_sum_assignment(-D)
    mapping = {col: row for row, col in zip(row_ind, col_ind)}
    aligned = np.array([mapping[x] for x in pred_labels])
    return aligned

# %% [markdown]
# ## 3. Setting up the function to calcuate the BAC

# %%
def calculate_bac(true_states, pred_states):
    """
    Compute the Balanced Accuracy (BAC) after aligning the predicted state labels.
    """
    aligned_pred = align_labels(true_states, pred_states)
    return balanced_accuracy_score(true_states, aligned_pred)

# %% [markdown]
# ## 4. Functions for model formulation
#
# ### 4.1 HMM With Nystrup (2021) initialization

# %%
def run_hmm(X, n_components=2, random_state=None):
    """
    Fit a Gaussian HMM to the data X.
    """
    model = hmm.GaussianHMM(
        n_components=n_components,
        covariance_type='diag',
        n_iter=100,
        random_state=random_state,
        init_params="mc",
        covars_prior=1.0
    )
    model.startprob_ = np.full(n_components, 1.0 / n_components)
    transmat = np.full((n_components, n_components), 0.05 / (n_components - 1))
    np.fill_diagonal(transmat, 0.95)
    model.transmat_ = transmat
    
    model.fit(X)
    pred_states = model.predict(X)
    return pred_states

# %% [markdown]
# ### 4.2 Normal (Standard) Jump Model with Grid Search over λ

# %%
def run_jump_model_grid_search(X, true_states, n_components=2, random_state=None):
    """
    Perform a grid search over lambda values for the Jump Model.
    
    Returns:
        best_labels: Predicted state sequence for the best lambda.
        best_bac: Best balanced accuracy achieved.
        best_lambda: The lambda value that achieved best_bac.
    """
    lambda_values = np.logspace(-2, 4, 14)
    best_bac = -1
    best_labels = None
    best_lambda = None
    
    for lam in lambda_values:
        model = JumpModel(
            n_components=n_components,
            jump_penalty=lam,
            cont=False,
            max_iter=10,
            random_state=random_state
        )
        model.fit(X)
        labels = model.labels_
        bac = calculate_bac(true_states, labels)
        if bac > best_bac:
            best_bac = bac
            best_labels = labels
            best_lambda = lam
    
    return best_labels, best_bac, best_lambda

# %% [markdown]
# ### 4.3 Sparse Jump Model with Grid Search over λ and kappa

# %%
def run_sparse_jump_model_grid_search(X, true_states, n_components=2, random_state=None):
    """
    Perform a grid search for the best combination of jump_penalty (lambda) and feature selection
    level (kappa) for the Sparse Jump Model (SJM).
    
    Returns:
        best_labels: Predicted state sequence for the best combination.
        best_bac: Best balanced accuracy achieved.
        best_lambda: The lambda value that achieved best_bac.
        best_kappa: The kappa value that achieved best_bac.
    """
    lambdas = np.logspace(-1, 2, 7)
    p = X.shape[1]
    kappas = np.linspace(1, np.sqrt(p), 14)
    
    best_bac = -1
    best_labels = None
    best_lambda = None
    best_kappa = None
    
    for lam in lambdas:
        for kappa in kappas:
            max_feats = kappa**2
            model = SparseJumpModel(
                n_components=n_components,
                jump_penalty=lam,
                cont=False,
                max_feats=max_feats,
                max_iter=10,
                random_state=random_state
            )
            model.fit(X)
            labels = model.labels_
            bac = calculate_bac(true_states, labels)
            if bac > best_bac:
                best_bac = bac
                best_labels = labels
                best_lambda = lam
                best_kappa = kappa
    return best_labels, best_bac, best_lambda, best_kappa

# %% [markdown]
# # 5. Main Execution
#  We split the code into three sections for each model and then combine results at the end.

# %%
def run_one_simulation(sim, T, P, mu):
    """
    Run a single simulation (HMM, Jump, Sparse Jump) and return:
      - BAC scores for HMM, Jump, Sparse Jump
      - Best lambda for Jump Model
      - Best lambda and best kappa for Sparse Jump Model
    """
    # Simulate data
    X, true_states = simulate_data(T, P, mu, random_state=sim)

    # Gaussian HMM
    pred_hmm = run_hmm(X, n_components=2, random_state=sim)
    bac_hmm = calculate_bac(true_states, pred_hmm)

    # Jump Model grid search for hyperparameters
    _, bac_jump, best_lambda_jump = run_jump_model_grid_search(
        X, true_states, n_components=2, random_state=sim
    )

    # Sparse Jump Model grid search for hyperparameters
    _, bac_sparse, best_lambda_sparse, best_kappa_sparse = run_sparse_jump_model_grid_search(
        X, true_states, n_components=2, random_state=sim
    )

    return bac_hmm, bac_jump, bac_sparse, best_lambda_jump, best_lambda_sparse, best_kappa_sparse

if __name__ == "__main__":
    # --- Settings ---
    T = 500
    mu_values = [0.02, 0.05, 0.1, 0.25, 0.5,]
    p_values = [15, 30, 60, 150, 300]
    n_simulations = 10  # Adjust as needed

    # Initialize lists to store summary results and raw simulation details
    final_rows = []          # for summary results per (mu, P) pair
    simulation_details = []  # for raw per-simulation results

    # Detect the number of CPU cores available
    num_cores = multiprocessing.cpu_count()
    print(f"Detected {num_cores} CPU cores.")

    # Main loop over mu and P pairs
    for mu in mu_values:
        for P in p_values:
            print(f"\nStarting simulations for mu = {mu}, P = {P}")

            # Run simulations in parallel (each simulation does its own grid search)
            results = Parallel(n_jobs=num_cores)(
                delayed(run_one_simulation)(sim, T, P, mu) 
                for sim in range(n_simulations)
            )

            # Unpack the results for this (mu, P) pair
            hmm_bac_list      = [res[0] for res in results]
            jump_bac_list     = [res[1] for res in results]
            sparse_bac_list   = [res[2] for res in results]
            lambda_jump_list  = [res[3] for res in results]
            lambda_sparse_list= [res[4] for res in results]
            kappa_sparse_list = [res[5] for res in results]

            # Save the raw simulation results and print each simulation's details
            for sim_idx, res in enumerate(results):
                simulation_details.append({
                    "mu": mu,
                    "P": P,
                    "sim": sim_idx,
                    "HMM_BAC": res[0],
                    "Jump_BAC": res[1],
                    "SparseJump_BAC": res[2],
                    "Jump_Lambda": res[3],
                    "Sparse_Lambda": res[4],
                    "Sparse_Kappa": res[5]
                })
                print(f"Simulation {sim_idx} for mu={mu}, P={P}: "
                      f"HMM_BAC = {res[0]:.3f}, Jump_BAC = {res[1]:.3f}, SparseJump_BAC = {res[2]:.3f}, "
                      f"Jump_Lambda = {res[3]:.3f}, Sparse_Lambda = {res[4]:.3f}, Sparse_Kappa = {res[5]:.3f}")

            # Compute summary statistics for BAC scores
            hmm_mean, hmm_std = np.mean(hmm_bac_list), np.std(hmm_bac_list)
            jump_mean, jump_std = np.mean(jump_bac_list), np.std(jump_bac_list)
            sparse_mean, sparse_std = np.mean(sparse_bac_list), np.std(sparse_bac_list)

            # Compute summary statistics for hyperparameters
            mean_lambda_jump = np.mean(lambda_jump_list)
            std_lambda_jump  = np.std(lambda_jump_list)
            unique_lambda_jump = len(np.unique(lambda_jump_list))
            
            mean_lambda_sparse = np.mean(lambda_sparse_list)
            std_lambda_sparse  = np.std(lambda_sparse_list)
            unique_lambda_sparse = len(np.unique(lambda_sparse_list))
            
            mean_kappa_sparse = np.mean(kappa_sparse_list)
            std_kappa_sparse  = np.std(kappa_sparse_list)
            unique_kappa_sparse = len(np.unique(kappa_sparse_list))
            
            # Compute one-sided Wilcoxon test: test if Sparse Jump BAC is greater than Jump BAC
            stat, pval = wilcoxon(sparse_bac_list, jump_bac_list, alternative="greater")
            if pval < 0.05:
                sparse_str = f"**{sparse_mean:.2f} ± {sparse_std:.2f}**"
            else:
                sparse_str = f"{sparse_mean:.2f} ± {sparse_std:.2f}"
            
            # Append summary results to final_rows
            final_rows.append({
                "mu": mu,
                "P": P,
                "HMM (mean ± std)": f"{hmm_mean:.2f} ± {hmm_std:.2f}",
                "Jump (mean ± std)": f"{jump_mean:.2f} ± {jump_std:.2f}",
                "Sparse Jump (mean ± std)": sparse_str,
                "p-value (Jump vs Sparse, Wilcoxon)": f"{pval:.3g}",
                "Jump Lambda (mean ± std, unique)": f"{mean_lambda_jump:.2f} ± {std_lambda_jump:.2f} (n={unique_lambda_jump})",
                "Sparse Lambda (mean ± std, unique)": f"{mean_lambda_sparse:.2f} ± {std_lambda_sparse:.2f} (n={unique_lambda_sparse})",
                "Sparse Kappa (mean ± std, unique)": f"{mean_kappa_sparse:.2f} ± {std_kappa_sparse:.2f} (n={unique_kappa_sparse})"
            })

            # Print summary for this (mu, P) pair
            print(
                f"Finished analysis for mu={mu}, P={P}\n"
                f"  HMM BAC = {hmm_mean:.3f} ± {hmm_std:.3f}\n"
                f"  Jump BAC = {jump_mean:.3f} ± {jump_std:.3f}\n"
                f"  Sparse Jump BAC = {sparse_mean:.3f} ± {sparse_std:.3f}\n"
                f"  Jump Lambda: {mean_lambda_jump:.2f} ± {std_lambda_jump:.2f} (n={unique_lambda_jump})\n"
                f"  Sparse Lambda: {mean_lambda_sparse:.2f} ± {std_lambda_sparse:.2f} (n={unique_lambda_sparse})\n"
                f"  Sparse Kappa: {mean_kappa_sparse:.2f} ± {std_kappa_sparse:.2f} (n={unique_kappa_sparse})\n"
                f"  p-value (Jump vs Sparse, Wilcoxon) = {pval:.3g}"
            )
# Out:
# Detected 16 CPU cores.
#
# Starting simulations for mu = 0.02, P = 15
# Simulation 0 for mu=0.02, P=15: HMM_BAC = 0.552, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.02, P=15: HMM_BAC = 0.563, Jump_BAC = 0.513, SparseJump_BAC = 0.547, Jump_Lambda = 0.010, Sparse_Lambda = 0.316, Sparse_Kappa = 1.000
# Simulation 2 for mu=0.02, P=15: HMM_BAC = 0.437, Jump_BAC = 0.518, SparseJump_BAC = 0.830, Jump_Lambda = 0.242, Sparse_Lambda = 10.000, Sparse_Kappa = 2.326
# Simulation 3 for mu=0.02, P=15: HMM_BAC = 0.417, Jump_BAC = 0.542, SparseJump_BAC = 0.664, Jump_Lambda = 0.702, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.02, P=15: HMM_BAC = 0.453, Jump_BAC = 0.566, SparseJump_BAC = 0.746, Jump_Lambda = 0.702, Sparse_Lambda = 10.000, Sparse_Kappa = 1.663
# Simulation 5 for mu=0.02, P=15: HMM_BAC = 0.400, Jump_BAC = 0.557, SparseJump_BAC = 0.748, Jump_Lambda = 0.702, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 6 for mu=0.02, P=15: HMM_BAC = 0.599, Jump_BAC = 0.668, SparseJump_BAC = 0.547, Jump_Lambda = 2.031, Sparse_Lambda = 0.316, Sparse_Kappa = 1.000
# Simulation 7 for mu=0.02, P=15: HMM_BAC = 0.496, Jump_BAC = 0.980, SparseJump_BAC = 0.842, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 8 for mu=0.02, P=15: HMM_BAC = 0.557, Jump_BAC = 0.545, SparseJump_BAC = 0.529, Jump_Lambda = 0.702, Sparse_Lambda = 1.000, Sparse_Kappa = 1.442
# Simulation 9 for mu=0.02, P=15: HMM_BAC = 0.314, Jump_BAC = 0.833, SparseJump_BAC = 0.975, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Finished analysis for mu=0.02, P=15
#   HMM BAC = 0.479 ± 0.085
#   Jump BAC = 0.672 ± 0.183
#   Sparse Jump BAC = 0.743 ± 0.163
#   Jump Lambda: 6.22 ± 14.43 (n=6)
#   Sparse Lambda: 7.96 ± 8.88 (n=5)
#   Sparse Kappa: 1.24 ± 0.42 (n=4)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.0549
#
# Starting simulations for mu = 0.02, P = 30
# Simulation 0 for mu=0.02, P=30: HMM_BAC = 0.602, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.02, P=30: HMM_BAC = 0.488, Jump_BAC = 0.500, SparseJump_BAC = 0.832, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 2 for mu=0.02, P=30: HMM_BAC = 0.492, Jump_BAC = 0.861, SparseJump_BAC = 0.774, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 3.411
# Simulation 3 for mu=0.02, P=30: HMM_BAC = 0.504, Jump_BAC = 0.563, SparseJump_BAC = 0.605, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 1.689
# Simulation 4 for mu=0.02, P=30: HMM_BAC = 0.527, Jump_BAC = 0.583, SparseJump_BAC = 0.606, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.066
# Simulation 5 for mu=0.02, P=30: HMM_BAC = 0.488, Jump_BAC = 0.528, SparseJump_BAC = 0.541, Jump_Lambda = 2.031, Sparse_Lambda = 1.000, Sparse_Kappa = 1.344
# Simulation 6 for mu=0.02, P=30: HMM_BAC = 0.517, Jump_BAC = 0.798, SparseJump_BAC = 0.572, Jump_Lambda = 17.013, Sparse_Lambda = 0.316, Sparse_Kappa = 2.378
# Simulation 7 for mu=0.02, P=30: HMM_BAC = 0.531, Jump_BAC = 0.558, SparseJump_BAC = 0.605, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 8 for mu=0.02, P=30: HMM_BAC = 0.512, Jump_BAC = 0.524, SparseJump_BAC = 0.554, Jump_Lambda = 0.702, Sparse_Lambda = 1.000, Sparse_Kappa = 2.378
# Simulation 9 for mu=0.02, P=30: HMM_BAC = 0.501, Jump_BAC = 0.529, SparseJump_BAC = 0.593, Jump_Lambda = 0.242, Sparse_Lambda = 3.162, Sparse_Kappa = 1.689
# Finished analysis for mu=0.02, P=30
#   HMM BAC = 0.516 ± 0.032
#   Jump BAC = 0.645 ± 0.166
#   Sparse Jump BAC = 0.668 ± 0.143
#   Jump Lambda: 6.98 ± 6.80 (n=5)
#   Sparse Lambda: 7.34 ± 8.90 (n=5)
#   Sparse Kappa: 1.90 ± 0.83 (n=6)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.187
#
# Starting simulations for mu = 0.02, P = 60
# Simulation 0 for mu=0.02, P=60: HMM_BAC = 0.548, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.02, P=60: HMM_BAC = 0.497, Jump_BAC = 0.513, SparseJump_BAC = 0.558, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 3.595
# Simulation 2 for mu=0.02, P=60: HMM_BAC = 0.514, Jump_BAC = 0.553, SparseJump_BAC = 0.588, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 3.595
# Simulation 3 for mu=0.02, P=60: HMM_BAC = 0.464, Jump_BAC = 0.500, SparseJump_BAC = 0.835, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.02, P=60: HMM_BAC = 0.527, Jump_BAC = 0.870, SparseJump_BAC = 0.888, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 5 for mu=0.02, P=60: HMM_BAC = 0.510, Jump_BAC = 0.516, SparseJump_BAC = 0.624, Jump_Lambda = 0.242, Sparse_Lambda = 10.000, Sparse_Kappa = 2.038
# Simulation 6 for mu=0.02, P=60: HMM_BAC = 0.530, Jump_BAC = 0.607, SparseJump_BAC = 0.583, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 5.670
# Simulation 7 for mu=0.02, P=60: HMM_BAC = 0.548, Jump_BAC = 0.893, SparseJump_BAC = 0.588, Jump_Lambda = 49.239, Sparse_Lambda = 3.162, Sparse_Kappa = 6.708
# Simulation 8 for mu=0.02, P=60: HMM_BAC = 0.505, Jump_BAC = 0.540, SparseJump_BAC = 0.559, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 3.076
# Simulation 9 for mu=0.02, P=60: HMM_BAC = 0.600, Jump_BAC = 0.626, SparseJump_BAC = 0.685, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 5.151
# Finished analysis for mu=0.02, P=60
#   HMM BAC = 0.524 ± 0.035
#   Jump BAC = 0.662 ± 0.177
#   Sparse Jump BAC = 0.691 ± 0.151
#   Jump Lambda: 31.95 ± 42.09 (n=6)
#   Sparse Lambda: 13.75 ± 12.04 (n=3)
#   Sparse Kappa: 3.28 ± 1.96 (n=7)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.0865
#
# Starting simulations for mu = 0.02, P = 150
# Simulation 0 for mu=0.02, P=150: HMM_BAC = 0.532, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 100.000, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.02, P=150: HMM_BAC = 0.519, Jump_BAC = 0.515, SparseJump_BAC = 0.539, Jump_Lambda = 0.242, Sparse_Lambda = 0.100, Sparse_Kappa = 3.596
# Simulation 2 for mu=0.02, P=150: HMM_BAC = 0.497, Jump_BAC = 0.506, SparseJump_BAC = 0.544, Jump_Lambda = 0.242, Sparse_Lambda = 1.000, Sparse_Kappa = 5.326
# Simulation 3 for mu=0.02, P=150: HMM_BAC = 0.413, Jump_BAC = 0.639, SparseJump_BAC = 0.697, Jump_Lambda = 49.239, Sparse_Lambda = 3.162, Sparse_Kappa = 3.596
# Simulation 4 for mu=0.02, P=150: HMM_BAC = 0.503, Jump_BAC = 0.508, SparseJump_BAC = 0.544, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 1.865
# Simulation 5 for mu=0.02, P=150: HMM_BAC = 0.481, Jump_BAC = 0.502, SparseJump_BAC = 0.590, Jump_Lambda = 0.010, Sparse_Lambda = 1.000, Sparse_Kappa = 1.865
# Simulation 6 for mu=0.02, P=150: HMM_BAC = 0.492, Jump_BAC = 0.559, SparseJump_BAC = 0.664, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 3.596
# Simulation 7 for mu=0.02, P=150: HMM_BAC = 0.534, Jump_BAC = 0.530, SparseJump_BAC = 0.579, Jump_Lambda = 0.010, Sparse_Lambda = 1.000, Sparse_Kappa = 2.730
# Simulation 8 for mu=0.02, P=150: HMM_BAC = 0.506, Jump_BAC = 0.508, SparseJump_BAC = 0.630, Jump_Lambda = 0.702, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 9 for mu=0.02, P=150: HMM_BAC = 0.514, Jump_BAC = 0.606, SparseJump_BAC = 0.724, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 2.730
# Finished analysis for mu=0.02, P=150
#   HMM BAC = 0.499 ± 0.033
#   Jump BAC = 0.587 ± 0.145
#   Sparse Jump BAC = 0.651 ± 0.132
#   Jump Lambda: 22.90 ± 42.51 (n=7)
#   Sparse Lambda: 18.95 ± 29.36 (n=6)
#   Sparse Kappa: 2.73 ± 1.28 (n=5)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.00384
#
# Starting simulations for mu = 0.02, P = 300
# Simulation 0 for mu=0.02, P=300: HMM_BAC = 0.504, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 412.463, Sparse_Lambda = 100.000, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.02, P=300: HMM_BAC = 0.516, Jump_BAC = 0.522, SparseJump_BAC = 0.578, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 2.255
# Simulation 2 for mu=0.02, P=300: HMM_BAC = 0.557, Jump_BAC = 0.598, SparseJump_BAC = 0.588, Jump_Lambda = 49.239, Sparse_Lambda = 10.000, Sparse_Kappa = 3.511
# Simulation 3 for mu=0.02, P=300: HMM_BAC = 0.531, Jump_BAC = 0.741, SparseJump_BAC = 0.885, Jump_Lambda = 142.510, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.02, P=300: HMM_BAC = 0.521, Jump_BAC = 0.537, SparseJump_BAC = 0.548, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 5 for mu=0.02, P=300: HMM_BAC = 0.513, Jump_BAC = 0.548, SparseJump_BAC = 0.562, Jump_Lambda = 17.013, Sparse_Lambda = 0.316, Sparse_Kappa = 3.511
# Simulation 6 for mu=0.02, P=300: HMM_BAC = 0.449, Jump_BAC = 0.500, SparseJump_BAC = 0.520, Jump_Lambda = 412.463, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 7 for mu=0.02, P=300: HMM_BAC = 0.490, Jump_BAC = 0.524, SparseJump_BAC = 0.632, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.255
# Simulation 8 for mu=0.02, P=300: HMM_BAC = 0.499, Jump_BAC = 0.514, SparseJump_BAC = 0.539, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 8.533
# Simulation 9 for mu=0.02, P=300: HMM_BAC = 0.515, Jump_BAC = 0.529, SparseJump_BAC = 0.644, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 3.511
# Finished analysis for mu=0.02, P=300
#   HMM BAC = 0.510 ± 0.027
#   Jump BAC = 0.601 ± 0.149
#   Sparse Jump BAC = 0.650 ± 0.153
#   Jump Lambda: 113.98 ± 153.84 (n=5)
#   Sparse Lambda: 26.68 ± 26.98 (n=4)
#   Sparse Kappa: 2.76 ± 2.19 (n=4)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.00543
#
# Starting simulations for mu = 0.05, P = 15
# Simulation 0 for mu=0.05, P=15: HMM_BAC = 0.552, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.05, P=15: HMM_BAC = 0.539, Jump_BAC = 0.716, SparseJump_BAC = 0.526, Jump_Lambda = 5.878, Sparse_Lambda = 0.100, Sparse_Kappa = 1.000
# Simulation 2 for mu=0.05, P=15: HMM_BAC = 0.433, Jump_BAC = 0.672, SparseJump_BAC = 0.837, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 2.547
# Simulation 3 for mu=0.05, P=15: HMM_BAC = 0.421, Jump_BAC = 0.559, SparseJump_BAC = 0.664, Jump_Lambda = 0.029, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.05, P=15: HMM_BAC = 0.453, Jump_BAC = 0.563, SparseJump_BAC = 0.592, Jump_Lambda = 0.702, Sparse_Lambda = 3.162, Sparse_Kappa = 1.442
# Simulation 5 for mu=0.05, P=15: HMM_BAC = 0.400, Jump_BAC = 0.570, SparseJump_BAC = 0.547, Jump_Lambda = 0.702, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 6 for mu=0.05, P=15: HMM_BAC = 0.601, Jump_BAC = 0.701, SparseJump_BAC = 0.557, Jump_Lambda = 2.031, Sparse_Lambda = 0.316, Sparse_Kappa = 1.000
# Simulation 7 for mu=0.05, P=15: HMM_BAC = 0.562, Jump_BAC = 0.997, SparseJump_BAC = 0.993, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 8 for mu=0.05, P=15: HMM_BAC = 0.555, Jump_BAC = 0.690, SparseJump_BAC = 0.593, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 9 for mu=0.05, P=15: HMM_BAC = 0.323, Jump_BAC = 0.833, SparseJump_BAC = 0.917, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.663
# Finished analysis for mu=0.05, P=15
#   HMM BAC = 0.484 ± 0.085
#   Jump BAC = 0.730 ± 0.156
#   Sparse Jump BAC = 0.723 ± 0.183
#   Jump Lambda: 7.44 ± 14.10 (n=5)
#   Sparse Lambda: 7.47 ± 8.84 (n=5)
#   Sparse Kappa: 1.27 ± 0.48 (n=4)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.571
#
# Starting simulations for mu = 0.05, P = 30
# Simulation 0 for mu=0.05, P=30: HMM_BAC = 0.602, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.05, P=30: HMM_BAC = 0.491, Jump_BAC = 0.557, SparseJump_BAC = 0.537, Jump_Lambda = 2.031, Sparse_Lambda = 0.316, Sparse_Kappa = 1.000
# Simulation 2 for mu=0.05, P=30: HMM_BAC = 0.492, Jump_BAC = 0.861, SparseJump_BAC = 0.552, Jump_Lambda = 17.013, Sparse_Lambda = 3.162, Sparse_Kappa = 3.411
# Simulation 3 for mu=0.05, P=30: HMM_BAC = 0.505, Jump_BAC = 0.563, SparseJump_BAC = 0.605, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 1.689
# Simulation 4 for mu=0.05, P=30: HMM_BAC = 0.531, Jump_BAC = 0.757, SparseJump_BAC = 0.554, Jump_Lambda = 17.013, Sparse_Lambda = 1.000, Sparse_Kappa = 2.722
# Simulation 5 for mu=0.05, P=30: HMM_BAC = 0.488, Jump_BAC = 0.528, SparseJump_BAC = 0.541, Jump_Lambda = 2.031, Sparse_Lambda = 1.000, Sparse_Kappa = 1.344
# Simulation 6 for mu=0.05, P=30: HMM_BAC = 0.517, Jump_BAC = 0.798, SparseJump_BAC = 0.568, Jump_Lambda = 17.013, Sparse_Lambda = 0.100, Sparse_Kappa = 1.689
# Simulation 7 for mu=0.05, P=30: HMM_BAC = 0.531, Jump_BAC = 0.562, SparseJump_BAC = 0.605, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 8 for mu=0.05, P=30: HMM_BAC = 0.512, Jump_BAC = 0.520, SparseJump_BAC = 0.553, Jump_Lambda = 0.010, Sparse_Lambda = 1.000, Sparse_Kappa = 1.689
# Simulation 9 for mu=0.05, P=30: HMM_BAC = 0.501, Jump_BAC = 0.584, SparseJump_BAC = 0.593, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 1.689
# Finished analysis for mu=0.05, P=30
#   HMM BAC = 0.517 ± 0.032
#   Jump BAC = 0.673 ± 0.160
#   Sparse Jump BAC = 0.611 ± 0.132
#   Jump Lambda: 7.82 ± 7.53 (n=3)
#   Sparse Lambda: 4.77 ± 9.03 (n=5)
#   Sparse Kappa: 1.72 ± 0.75 (n=5)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.703
#
# Starting simulations for mu = 0.05, P = 60
# Simulation 0 for mu=0.05, P=60: HMM_BAC = 0.548, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.05, P=60: HMM_BAC = 0.498, Jump_BAC = 0.513, SparseJump_BAC = 0.558, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 3.595
# Simulation 2 for mu=0.05, P=60: HMM_BAC = 0.514, Jump_BAC = 0.556, SparseJump_BAC = 0.579, Jump_Lambda = 2.031, Sparse_Lambda = 1.000, Sparse_Kappa = 3.595
# Simulation 3 for mu=0.05, P=60: HMM_BAC = 0.465, Jump_BAC = 0.500, SparseJump_BAC = 0.835, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.05, P=60: HMM_BAC = 0.527, Jump_BAC = 0.870, SparseJump_BAC = 0.888, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 5 for mu=0.05, P=60: HMM_BAC = 0.511, Jump_BAC = 0.516, SparseJump_BAC = 0.624, Jump_Lambda = 0.242, Sparse_Lambda = 10.000, Sparse_Kappa = 2.038
# Simulation 6 for mu=0.05, P=60: HMM_BAC = 0.530, Jump_BAC = 0.607, SparseJump_BAC = 0.584, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 5.670
# Simulation 7 for mu=0.05, P=60: HMM_BAC = 0.548, Jump_BAC = 0.893, SparseJump_BAC = 0.588, Jump_Lambda = 49.239, Sparse_Lambda = 3.162, Sparse_Kappa = 6.708
# Simulation 8 for mu=0.05, P=60: HMM_BAC = 0.505, Jump_BAC = 0.540, SparseJump_BAC = 0.559, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 3.076
# Simulation 9 for mu=0.05, P=60: HMM_BAC = 0.600, Jump_BAC = 0.626, SparseJump_BAC = 0.685, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 5.151
# Finished analysis for mu=0.05, P=60
#   HMM BAC = 0.525 ± 0.034
#   Jump BAC = 0.662 ± 0.176
#   Sparse Jump BAC = 0.690 ± 0.151
#   Jump Lambda: 31.95 ± 42.09 (n=6)
#   Sparse Lambda: 13.54 ± 12.24 (n=4)
#   Sparse Kappa: 3.28 ± 1.96 (n=7)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.0865
#
# Starting simulations for mu = 0.05, P = 150
# Simulation 0 for mu=0.05, P=150: HMM_BAC = 0.532, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 100.000, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.05, P=150: HMM_BAC = 0.519, Jump_BAC = 0.515, SparseJump_BAC = 0.539, Jump_Lambda = 0.242, Sparse_Lambda = 0.100, Sparse_Kappa = 3.596
# Simulation 2 for mu=0.05, P=150: HMM_BAC = 0.497, Jump_BAC = 0.508, SparseJump_BAC = 0.549, Jump_Lambda = 0.702, Sparse_Lambda = 1.000, Sparse_Kappa = 5.326
# Simulation 3 for mu=0.05, P=150: HMM_BAC = 0.413, Jump_BAC = 0.639, SparseJump_BAC = 0.697, Jump_Lambda = 49.239, Sparse_Lambda = 3.162, Sparse_Kappa = 3.596
# Simulation 4 for mu=0.05, P=150: HMM_BAC = 0.503, Jump_BAC = 0.508, SparseJump_BAC = 0.544, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 1.865
# Simulation 5 for mu=0.05, P=150: HMM_BAC = 0.481, Jump_BAC = 0.502, SparseJump_BAC = 0.590, Jump_Lambda = 0.010, Sparse_Lambda = 1.000, Sparse_Kappa = 1.865
# Simulation 6 for mu=0.05, P=150: HMM_BAC = 0.492, Jump_BAC = 0.559, SparseJump_BAC = 0.664, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 3.596
# Simulation 7 for mu=0.05, P=150: HMM_BAC = 0.534, Jump_BAC = 0.530, SparseJump_BAC = 0.579, Jump_Lambda = 0.010, Sparse_Lambda = 1.000, Sparse_Kappa = 2.730
# Simulation 8 for mu=0.05, P=150: HMM_BAC = 0.506, Jump_BAC = 0.508, SparseJump_BAC = 0.630, Jump_Lambda = 2.031, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 9 for mu=0.05, P=150: HMM_BAC = 0.514, Jump_BAC = 0.606, SparseJump_BAC = 0.724, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 2.730
# Finished analysis for mu=0.05, P=150
#   HMM BAC = 0.499 ± 0.033
#   Jump BAC = 0.587 ± 0.144
#   Sparse Jump BAC = 0.652 ± 0.132
#   Jump Lambda: 23.08 ± 42.42 (n=7)
#   Sparse Lambda: 18.95 ± 29.36 (n=6)
#   Sparse Kappa: 2.73 ± 1.28 (n=5)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.00384
#
# Starting simulations for mu = 0.05, P = 300
# Simulation 0 for mu=0.05, P=300: HMM_BAC = 0.504, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 412.463, Sparse_Lambda = 100.000, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.05, P=300: HMM_BAC = 0.516, Jump_BAC = 0.522, SparseJump_BAC = 0.578, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 2.255
# Simulation 2 for mu=0.05, P=300: HMM_BAC = 0.557, Jump_BAC = 0.598, SparseJump_BAC = 0.588, Jump_Lambda = 49.239, Sparse_Lambda = 10.000, Sparse_Kappa = 3.511
# Simulation 3 for mu=0.05, P=300: HMM_BAC = 0.531, Jump_BAC = 0.741, SparseJump_BAC = 0.885, Jump_Lambda = 142.510, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.05, P=300: HMM_BAC = 0.521, Jump_BAC = 0.533, SparseJump_BAC = 0.548, Jump_Lambda = 142.510, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 5 for mu=0.05, P=300: HMM_BAC = 0.513, Jump_BAC = 0.548, SparseJump_BAC = 0.562, Jump_Lambda = 17.013, Sparse_Lambda = 0.316, Sparse_Kappa = 3.511
# Simulation 6 for mu=0.05, P=300: HMM_BAC = 0.449, Jump_BAC = 0.500, SparseJump_BAC = 0.520, Jump_Lambda = 412.463, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 7 for mu=0.05, P=300: HMM_BAC = 0.490, Jump_BAC = 0.524, SparseJump_BAC = 0.632, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.255
# Simulation 8 for mu=0.05, P=300: HMM_BAC = 0.499, Jump_BAC = 0.514, SparseJump_BAC = 0.539, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 8.533
# Simulation 9 for mu=0.05, P=300: HMM_BAC = 0.515, Jump_BAC = 0.529, SparseJump_BAC = 0.644, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 3.511
# Finished analysis for mu=0.05, P=300
#   HMM BAC = 0.510 ± 0.027
#   Jump BAC = 0.601 ± 0.149
#   Sparse Jump BAC = 0.650 ± 0.153
#   Jump Lambda: 126.53 ± 150.50 (n=5)
#   Sparse Lambda: 26.68 ± 26.98 (n=4)
#   Sparse Kappa: 2.76 ± 2.19 (n=4)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.00543
#
# Starting simulations for mu = 0.1, P = 15
# Simulation 0 for mu=0.1, P=15: HMM_BAC = 0.552, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.1, P=15: HMM_BAC = 0.456, Jump_BAC = 0.720, SparseJump_BAC = 0.515, Jump_Lambda = 5.878, Sparse_Lambda = 1.000, Sparse_Kappa = 1.000
# Simulation 2 for mu=0.1, P=15: HMM_BAC = 0.423, Jump_BAC = 0.980, SparseJump_BAC = 0.980, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.105
# Simulation 3 for mu=0.1, P=15: HMM_BAC = 0.441, Jump_BAC = 0.665, SparseJump_BAC = 0.604, Jump_Lambda = 0.702, Sparse_Lambda = 0.100, Sparse_Kappa = 1.221
# Simulation 4 for mu=0.1, P=15: HMM_BAC = 0.852, Jump_BAC = 0.992, SparseJump_BAC = 0.903, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.768
# Simulation 5 for mu=0.1, P=15: HMM_BAC = 0.551, Jump_BAC = 0.585, SparseJump_BAC = 0.511, Jump_Lambda = 0.242, Sparse_Lambda = 1.000, Sparse_Kappa = 1.000
# Simulation 6 for mu=0.1, P=15: HMM_BAC = 0.555, Jump_BAC = 0.769, SparseJump_BAC = 0.769, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.326
# Simulation 7 for mu=0.1, P=15: HMM_BAC = 0.494, Jump_BAC = 0.980, SparseJump_BAC = 0.993, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 8 for mu=0.1, P=15: HMM_BAC = 0.995, Jump_BAC = 0.995, SparseJump_BAC = 0.995, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 2.547
# Simulation 9 for mu=0.1, P=15: HMM_BAC = 0.320, Jump_BAC = 0.833, SparseJump_BAC = 0.917, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.663
# Finished analysis for mu=0.1, P=15
#   HMM BAC = 0.564 ± 0.195
#   Jump BAC = 0.852 ± 0.150
#   Sparse Jump BAC = 0.819 ± 0.193
#   Jump Lambda: 8.75 ± 13.68 (n=5)
#   Sparse Lambda: 8.69 ± 8.70 (n=5)
#   Sparse Kappa: 1.66 ± 0.68 (n=7)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.876
#
# Starting simulations for mu = 0.1, P = 30
# Simulation 0 for mu=0.1, P=30: HMM_BAC = 0.602, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.1, P=30: HMM_BAC = 0.491, Jump_BAC = 0.992, SparseJump_BAC = 0.996, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 2.722
# Simulation 2 for mu=0.1, P=30: HMM_BAC = 0.492, Jump_BAC = 0.985, SparseJump_BAC = 0.972, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 1.344
# Simulation 3 for mu=0.1, P=30: HMM_BAC = 0.505, Jump_BAC = 0.563, SparseJump_BAC = 0.605, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 1.689
# Simulation 4 for mu=0.1, P=30: HMM_BAC = 0.534, Jump_BAC = 0.850, SparseJump_BAC = 0.870, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.033
# Simulation 5 for mu=0.1, P=30: HMM_BAC = 0.488, Jump_BAC = 0.528, SparseJump_BAC = 0.541, Jump_Lambda = 2.031, Sparse_Lambda = 1.000, Sparse_Kappa = 1.344
# Simulation 6 for mu=0.1, P=30: HMM_BAC = 0.518, Jump_BAC = 0.798, SparseJump_BAC = 0.987, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 2.033
# Simulation 7 for mu=0.1, P=30: HMM_BAC = 0.531, Jump_BAC = 0.541, SparseJump_BAC = 0.605, Jump_Lambda = 0.702, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 8 for mu=0.1, P=30: HMM_BAC = 0.513, Jump_BAC = 0.527, SparseJump_BAC = 0.561, Jump_Lambda = 0.702, Sparse_Lambda = 1.000, Sparse_Kappa = 2.033
# Simulation 9 for mu=0.1, P=30: HMM_BAC = 0.501, Jump_BAC = 0.528, SparseJump_BAC = 0.747, Jump_Lambda = 0.242, Sparse_Lambda = 10.000, Sparse_Kappa = 1.689
# Finished analysis for mu=0.1, P=30
#   HMM BAC = 0.518 ± 0.032
#   Jump BAC = 0.731 ± 0.203
#   Sparse Jump BAC = 0.788 ± 0.187
#   Jump Lambda: 7.96 ± 7.53 (n=5)
#   Sparse Lambda: 8.99 ± 8.44 (n=4)
#   Sparse Kappa: 1.69 ± 0.51 (n=5)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.0104
#
# Starting simulations for mu = 0.1, P = 60
# Simulation 0 for mu=0.1, P=60: HMM_BAC = 0.548, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.1, P=60: HMM_BAC = 0.502, Jump_BAC = 0.510, SparseJump_BAC = 0.558, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 3.595
# Simulation 2 for mu=0.1, P=60: HMM_BAC = 0.514, Jump_BAC = 0.554, SparseJump_BAC = 0.579, Jump_Lambda = 2.031, Sparse_Lambda = 1.000, Sparse_Kappa = 3.595
# Simulation 3 for mu=0.1, P=60: HMM_BAC = 0.465, Jump_BAC = 0.500, SparseJump_BAC = 0.835, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.1, P=60: HMM_BAC = 0.527, Jump_BAC = 0.870, SparseJump_BAC = 0.890, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.519
# Simulation 5 for mu=0.1, P=60: HMM_BAC = 0.511, Jump_BAC = 0.515, SparseJump_BAC = 0.624, Jump_Lambda = 0.242, Sparse_Lambda = 10.000, Sparse_Kappa = 2.038
# Simulation 6 for mu=0.1, P=60: HMM_BAC = 0.530, Jump_BAC = 0.593, SparseJump_BAC = 0.582, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 5.670
# Simulation 7 for mu=0.1, P=60: HMM_BAC = 0.548, Jump_BAC = 0.893, SparseJump_BAC = 0.588, Jump_Lambda = 49.239, Sparse_Lambda = 3.162, Sparse_Kappa = 6.708
# Simulation 8 for mu=0.1, P=60: HMM_BAC = 0.506, Jump_BAC = 0.552, SparseJump_BAC = 0.559, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 3.076
# Simulation 9 for mu=0.1, P=60: HMM_BAC = 0.600, Jump_BAC = 0.626, SparseJump_BAC = 0.688, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 4.632
# Finished analysis for mu=0.1, P=60
#   HMM BAC = 0.525 ± 0.034
#   Jump BAC = 0.661 ± 0.176
#   Sparse Jump BAC = 0.690 ± 0.152
#   Jump Lambda: 31.95 ± 42.09 (n=6)
#   Sparse Lambda: 13.54 ± 12.24 (n=4)
#   Sparse Kappa: 3.28 ± 1.86 (n=8)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.0693
#
# Starting simulations for mu = 0.1, P = 150
# Simulation 0 for mu=0.1, P=150: HMM_BAC = 0.532, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 100.000, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.1, P=150: HMM_BAC = 0.519, Jump_BAC = 0.515, SparseJump_BAC = 0.574, Jump_Lambda = 0.242, Sparse_Lambda = 31.623, Sparse_Kappa = 9.652
# Simulation 2 for mu=0.1, P=150: HMM_BAC = 0.497, Jump_BAC = 0.508, SparseJump_BAC = 0.549, Jump_Lambda = 0.702, Sparse_Lambda = 1.000, Sparse_Kappa = 5.326
# Simulation 3 for mu=0.1, P=150: HMM_BAC = 0.413, Jump_BAC = 0.639, SparseJump_BAC = 0.697, Jump_Lambda = 49.239, Sparse_Lambda = 3.162, Sparse_Kappa = 3.596
# Simulation 4 for mu=0.1, P=150: HMM_BAC = 0.503, Jump_BAC = 0.508, SparseJump_BAC = 0.764, Jump_Lambda = 2.031, Sparse_Lambda = 100.000, Sparse_Kappa = 1.000
# Simulation 5 for mu=0.1, P=150: HMM_BAC = 0.481, Jump_BAC = 0.502, SparseJump_BAC = 0.590, Jump_Lambda = 0.010, Sparse_Lambda = 1.000, Sparse_Kappa = 1.865
# Simulation 6 for mu=0.1, P=150: HMM_BAC = 0.489, Jump_BAC = 0.562, SparseJump_BAC = 0.578, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 5.326
# Simulation 7 for mu=0.1, P=150: HMM_BAC = 0.534, Jump_BAC = 0.530, SparseJump_BAC = 0.579, Jump_Lambda = 0.010, Sparse_Lambda = 1.000, Sparse_Kappa = 2.730
# Simulation 8 for mu=0.1, P=150: HMM_BAC = 0.506, Jump_BAC = 0.510, SparseJump_BAC = 0.630, Jump_Lambda = 2.031, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 9 for mu=0.1, P=150: HMM_BAC = 0.514, Jump_BAC = 0.606, SparseJump_BAC = 0.724, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 2.730
# Finished analysis for mu=0.1, P=150
#   HMM BAC = 0.499 ± 0.033
#   Jump BAC = 0.588 ± 0.144
#   Sparse Jump BAC = 0.668 ± 0.130
#   Jump Lambda: 23.08 ± 42.42 (n=7)
#   Sparse Lambda: 28.94 ± 37.20 (n=5)
#   Sparse Kappa: 3.42 ± 2.59 (n=6)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.00384
#
# Starting simulations for mu = 0.1, P = 300
# Simulation 0 for mu=0.1, P=300: HMM_BAC = 0.504, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 412.463, Sparse_Lambda = 100.000, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.1, P=300: HMM_BAC = 0.516, Jump_BAC = 0.522, SparseJump_BAC = 0.578, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 2.255
# Simulation 2 for mu=0.1, P=300: HMM_BAC = 0.557, Jump_BAC = 0.598, SparseJump_BAC = 0.588, Jump_Lambda = 49.239, Sparse_Lambda = 10.000, Sparse_Kappa = 3.511
# Simulation 3 for mu=0.1, P=300: HMM_BAC = 0.531, Jump_BAC = 0.741, SparseJump_BAC = 0.885, Jump_Lambda = 142.510, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.1, P=300: HMM_BAC = 0.521, Jump_BAC = 0.529, SparseJump_BAC = 0.548, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 5 for mu=0.1, P=300: HMM_BAC = 0.513, Jump_BAC = 0.548, SparseJump_BAC = 0.562, Jump_Lambda = 17.013, Sparse_Lambda = 0.316, Sparse_Kappa = 3.511
# Simulation 6 for mu=0.1, P=300: HMM_BAC = 0.449, Jump_BAC = 0.500, SparseJump_BAC = 0.520, Jump_Lambda = 412.463, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 7 for mu=0.1, P=300: HMM_BAC = 0.490, Jump_BAC = 0.524, SparseJump_BAC = 0.632, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.255
# Simulation 8 for mu=0.1, P=300: HMM_BAC = 0.500, Jump_BAC = 0.514, SparseJump_BAC = 0.539, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 8.533
# Simulation 9 for mu=0.1, P=300: HMM_BAC = 0.515, Jump_BAC = 0.529, SparseJump_BAC = 0.644, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 3.511
# Finished analysis for mu=0.1, P=300
#   HMM BAC = 0.510 ± 0.027
#   Jump BAC = 0.600 ± 0.149
#   Sparse Jump BAC = 0.650 ± 0.153
#   Jump Lambda: 113.98 ± 153.84 (n=5)
#   Sparse Lambda: 26.68 ± 26.98 (n=4)
#   Sparse Kappa: 2.76 ± 2.19 (n=4)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.00543
#
# Starting simulations for mu = 0.25, P = 15
# Simulation 0 for mu=0.25, P=15: HMM_BAC = 0.552, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.25, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 3.873
# Simulation 2 for mu=0.25, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 3.431
# Simulation 3 for mu=0.25, P=15: HMM_BAC = 0.885, Jump_BAC = 0.999, SparseJump_BAC = 0.999, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.221
# Simulation 4 for mu=0.25, P=15: HMM_BAC = 0.997, Jump_BAC = 0.997, SparseJump_BAC = 0.997, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.768
# Simulation 5 for mu=0.25, P=15: HMM_BAC = 0.998, Jump_BAC = 0.999, SparseJump_BAC = 0.998, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.210
# Simulation 6 for mu=0.25, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.652
# Simulation 7 for mu=0.25, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 0.994, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.884
# Simulation 8 for mu=0.25, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 2.989
# Simulation 9 for mu=0.25, P=15: HMM_BAC = 0.376, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.663
# Finished analysis for mu=0.25, P=15
#   HMM BAC = 0.881 ± 0.215
#   Jump BAC = 1.000 ± 0.001
#   Sparse Jump BAC = 0.999 ± 0.002
#   Jump Lambda: 10.21 ± 13.01 (n=2)
#   Sparse Lambda: 10.11 ± 7.80 (n=3)
#   Sparse Kappa: 2.57 ± 0.99 (n=10)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.91
#
# Starting simulations for mu = 0.25, P = 30
# Simulation 0 for mu=0.25, P=30: HMM_BAC = 0.602, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.25, P=30: HMM_BAC = 0.490, Jump_BAC = 0.992, SparseJump_BAC = 0.996, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.033
# Simulation 2 for mu=0.25, P=30: HMM_BAC = 0.490, Jump_BAC = 1.000, SparseJump_BAC = 0.989, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.722
# Simulation 3 for mu=0.25, P=30: HMM_BAC = 0.505, Jump_BAC = 0.563, SparseJump_BAC = 0.900, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 1.689
# Simulation 4 for mu=0.25, P=30: HMM_BAC = 0.539, Jump_BAC = 0.992, SparseJump_BAC = 0.996, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.378
# Simulation 5 for mu=0.25, P=30: HMM_BAC = 0.475, Jump_BAC = 0.797, SparseJump_BAC = 0.827, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 6 for mu=0.25, P=30: HMM_BAC = 0.519, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.033
# Simulation 7 for mu=0.25, P=30: HMM_BAC = 0.530, Jump_BAC = 0.941, SparseJump_BAC = 0.941, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.689
# Simulation 8 for mu=0.25, P=30: HMM_BAC = 0.519, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.411
# Simulation 9 for mu=0.25, P=30: HMM_BAC = 0.501, Jump_BAC = 0.998, SparseJump_BAC = 0.747, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 1.689
# Finished analysis for mu=0.25, P=30
#   HMM BAC = 0.517 ± 0.034
#   Jump BAC = 0.928 ± 0.136
#   Sparse Jump BAC = 0.940 ± 0.084
#   Jump Lambda: 7.72 ± 4.78 (n=3)
#   Sparse Lambda: 12.16 ± 6.49 (n=2)
#   Sparse Kappa: 1.96 ± 0.70 (n=6)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.3
#
# Starting simulations for mu = 0.25, P = 60
# Simulation 0 for mu=0.25, P=60: HMM_BAC = 0.548, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.25, P=60: HMM_BAC = 0.503, Jump_BAC = 1.000, SparseJump_BAC = 0.989, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 3.076
# Simulation 2 for mu=0.25, P=60: HMM_BAC = 0.515, Jump_BAC = 0.982, SparseJump_BAC = 0.993, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 2.038
# Simulation 3 for mu=0.25, P=60: HMM_BAC = 0.415, Jump_BAC = 0.500, SparseJump_BAC = 0.835, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.25, P=60: HMM_BAC = 0.532, Jump_BAC = 0.979, SparseJump_BAC = 0.997, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 3.076
# Simulation 5 for mu=0.25, P=60: HMM_BAC = 0.511, Jump_BAC = 0.529, SparseJump_BAC = 0.796, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 1.519
# Simulation 6 for mu=0.25, P=60: HMM_BAC = 0.529, Jump_BAC = 0.993, SparseJump_BAC = 0.993, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 2.557
# Simulation 7 for mu=0.25, P=60: HMM_BAC = 0.549, Jump_BAC = 0.893, SparseJump_BAC = 0.588, Jump_Lambda = 49.239, Sparse_Lambda = 3.162, Sparse_Kappa = 6.708
# Simulation 8 for mu=0.25, P=60: HMM_BAC = 0.504, Jump_BAC = 0.998, SparseJump_BAC = 1.000, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.519
# Simulation 9 for mu=0.25, P=60: HMM_BAC = 0.600, Jump_BAC = 0.626, SparseJump_BAC = 0.685, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 5.151
# Finished analysis for mu=0.25, P=60
#   HMM BAC = 0.521 ± 0.045
#   Jump BAC = 0.850 ± 0.200
#   Sparse Jump BAC = 0.888 ± 0.146
#   Jump Lambda: 37.73 ± 38.47 (n=4)
#   Sparse Lambda: 19.44 ± 12.41 (n=3)
#   Sparse Kappa: 2.76 ± 1.77 (n=7)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.104
#
# Starting simulations for mu = 0.25, P = 150
# Simulation 0 for mu=0.25, P=150: HMM_BAC = 0.532, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 100.000, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.25, P=150: HMM_BAC = 0.519, Jump_BAC = 0.515, SparseJump_BAC = 0.996, Jump_Lambda = 0.242, Sparse_Lambda = 100.000, Sparse_Kappa = 2.730
# Simulation 2 for mu=0.25, P=150: HMM_BAC = 0.497, Jump_BAC = 0.846, SparseJump_BAC = 0.544, Jump_Lambda = 142.510, Sparse_Lambda = 1.000, Sparse_Kappa = 5.326
# Simulation 3 for mu=0.25, P=150: HMM_BAC = 0.413, Jump_BAC = 0.639, SparseJump_BAC = 0.697, Jump_Lambda = 49.239, Sparse_Lambda = 3.162, Sparse_Kappa = 3.596
# Simulation 4 for mu=0.25, P=150: HMM_BAC = 0.503, Jump_BAC = 0.787, SparseJump_BAC = 0.766, Jump_Lambda = 142.510, Sparse_Lambda = 100.000, Sparse_Kappa = 2.730
# Simulation 5 for mu=0.25, P=150: HMM_BAC = 0.481, Jump_BAC = 0.502, SparseJump_BAC = 0.590, Jump_Lambda = 0.010, Sparse_Lambda = 1.000, Sparse_Kappa = 1.865
# Simulation 6 for mu=0.25, P=150: HMM_BAC = 0.489, Jump_BAC = 0.543, SparseJump_BAC = 1.000, Jump_Lambda = 17.013, Sparse_Lambda = 100.000, Sparse_Kappa = 2.730
# Simulation 7 for mu=0.25, P=150: HMM_BAC = 0.534, Jump_BAC = 0.530, SparseJump_BAC = 0.563, Jump_Lambda = 0.010, Sparse_Lambda = 1.000, Sparse_Kappa = 1.865
# Simulation 8 for mu=0.25, P=150: HMM_BAC = 0.508, Jump_BAC = 0.510, SparseJump_BAC = 0.997, Jump_Lambda = 2.031, Sparse_Lambda = 100.000, Sparse_Kappa = 1.865
# Simulation 9 for mu=0.25, P=150: HMM_BAC = 0.514, Jump_BAC = 0.606, SparseJump_BAC = 0.724, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 2.730
# Finished analysis for mu=0.25, P=150
#   HMM BAC = 0.499 ± 0.033
#   Jump BAC = 0.648 ± 0.164
#   Sparse Jump BAC = 0.788 ± 0.184
#   Jump Lambda: 51.31 ± 61.33 (n=6)
#   Sparse Lambda: 51.62 ± 48.45 (n=4)
#   Sparse Kappa: 2.64 ± 1.12 (n=5)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.0332
#
# Starting simulations for mu = 0.25, P = 300
# Simulation 0 for mu=0.25, P=300: HMM_BAC = 0.504, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 412.463, Sparse_Lambda = 100.000, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.25, P=300: HMM_BAC = 0.516, Jump_BAC = 0.522, SparseJump_BAC = 0.578, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 2.255
# Simulation 2 for mu=0.25, P=300: HMM_BAC = 0.557, Jump_BAC = 0.598, SparseJump_BAC = 0.985, Jump_Lambda = 49.239, Sparse_Lambda = 100.000, Sparse_Kappa = 2.255
# Simulation 3 for mu=0.25, P=300: HMM_BAC = 0.531, Jump_BAC = 0.741, SparseJump_BAC = 0.885, Jump_Lambda = 142.510, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.25, P=300: HMM_BAC = 0.521, Jump_BAC = 0.515, SparseJump_BAC = 0.548, Jump_Lambda = 0.010, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 5 for mu=0.25, P=300: HMM_BAC = 0.513, Jump_BAC = 0.548, SparseJump_BAC = 0.562, Jump_Lambda = 17.013, Sparse_Lambda = 0.316, Sparse_Kappa = 3.511
# Simulation 6 for mu=0.25, P=300: HMM_BAC = 0.449, Jump_BAC = 0.500, SparseJump_BAC = 0.520, Jump_Lambda = 412.463, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 7 for mu=0.25, P=300: HMM_BAC = 0.488, Jump_BAC = 0.551, SparseJump_BAC = 0.673, Jump_Lambda = 17.013, Sparse_Lambda = 0.100, Sparse_Kappa = 3.511
# Simulation 8 for mu=0.25, P=300: HMM_BAC = 0.500, Jump_BAC = 0.545, SparseJump_BAC = 0.539, Jump_Lambda = 142.510, Sparse_Lambda = 31.623, Sparse_Kappa = 8.533
# Simulation 9 for mu=0.25, P=300: HMM_BAC = 0.515, Jump_BAC = 0.529, SparseJump_BAC = 0.644, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 3.511
# Finished analysis for mu=0.25, P=300
#   HMM BAC = 0.509 ± 0.027
#   Jump BAC = 0.605 ± 0.147
#   Sparse Jump BAC = 0.693 ± 0.180
#   Jump Lambda: 125.95 ± 150.98 (n=5)
#   Sparse Lambda: 34.69 ± 34.88 (n=5)
#   Sparse Kappa: 2.76 ± 2.19 (n=4)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.00543
#
# Starting simulations for mu = 0.5, P = 15
# Simulation 0 for mu=0.5, P=15: HMM_BAC = 0.552, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.5, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 3.652
# Simulation 2 for mu=0.5, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 3.210
# Simulation 3 for mu=0.5, P=15: HMM_BAC = 0.998, Jump_BAC = 0.999, SparseJump_BAC = 0.999, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 2.768
# Simulation 4 for mu=0.5, P=15: HMM_BAC = 0.997, Jump_BAC = 0.997, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.221
# Simulation 5 for mu=0.5, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 2.326
# Simulation 6 for mu=0.5, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 3.210
# Simulation 7 for mu=0.5, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 2.547
# Simulation 8 for mu=0.5, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 2.105
# Simulation 9 for mu=0.5, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 3.431
# Finished analysis for mu=0.5, P=15
#   HMM BAC = 0.955 ± 0.134
#   Jump BAC = 1.000 ± 0.001
#   Sparse Jump BAC = 1.000 ± 0.000
#   Jump Lambda: 9.44 ± 13.35 (n=3)
#   Sparse Lambda: 7.38 ± 8.52 (n=3)
#   Sparse Kappa: 2.55 ± 0.86 (n=9)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.159
#
# Starting simulations for mu = 0.5, P = 30
# Simulation 0 for mu=0.5, P=30: HMM_BAC = 0.602, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.5, P=30: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.755
# Simulation 2 for mu=0.5, P=30: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 3.411
# Simulation 3 for mu=0.5, P=30: HMM_BAC = 0.456, Jump_BAC = 0.989, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.722
# Simulation 4 for mu=0.5, P=30: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 3.755
# Simulation 5 for mu=0.5, P=30: HMM_BAC = 0.476, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 1.344
# Simulation 6 for mu=0.5, P=30: HMM_BAC = 0.527, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 3.755
# Simulation 7 for mu=0.5, P=30: HMM_BAC = 0.530, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.344
# Simulation 8 for mu=0.5, P=30: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.033
# Simulation 9 for mu=0.5, P=30: HMM_BAC = 0.542, Jump_BAC = 1.000, SparseJump_BAC = 0.999, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.378
# Finished analysis for mu=0.5, P=30
#   HMM BAC = 0.713 ± 0.237
#   Jump BAC = 0.999 ± 0.003
#   Sparse Jump BAC = 1.000 ± 0.000
#   Jump Lambda: 5.45 ± 4.26 (n=3)
#   Sparse Lambda: 10.11 ± 7.80 (n=3)
#   Sparse Kappa: 2.55 ± 1.04 (n=7)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.327
#
# Starting simulations for mu = 0.5, P = 60
# Simulation 0 for mu=0.5, P=60: HMM_BAC = 0.548, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.5, P=60: HMM_BAC = 0.498, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.076
# Simulation 2 for mu=0.5, P=60: HMM_BAC = 0.515, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.595
# Simulation 3 for mu=0.5, P=60: HMM_BAC = 0.417, Jump_BAC = 1.000, SparseJump_BAC = 0.999, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 2.038
# Simulation 4 for mu=0.5, P=60: HMM_BAC = 0.560, Jump_BAC = 0.996, SparseJump_BAC = 0.997, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.038
# Simulation 5 for mu=0.5, P=60: HMM_BAC = 0.511, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 1.519
# Simulation 6 for mu=0.5, P=60: HMM_BAC = 0.530, Jump_BAC = 0.993, SparseJump_BAC = 0.993, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.557
# Simulation 7 for mu=0.5, P=60: HMM_BAC = 0.549, Jump_BAC = 0.999, SparseJump_BAC = 0.999, Jump_Lambda = 49.239, Sparse_Lambda = 100.000, Sparse_Kappa = 1.519
# Simulation 8 for mu=0.5, P=60: HMM_BAC = 0.505, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.076
# Simulation 9 for mu=0.5, P=60: HMM_BAC = 0.600, Jump_BAC = 0.627, SparseJump_BAC = 0.685, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 5.151
# Finished analysis for mu=0.5, P=60
#   HMM BAC = 0.523 ± 0.046
#   Jump BAC = 0.961 ± 0.111
#   Sparse Jump BAC = 0.967 ± 0.094
#   Jump Lambda: 28.94 ± 41.53 (n=5)
#   Sparse Lambda: 24.80 ± 27.13 (n=4)
#   Sparse Kappa: 2.56 ± 1.16 (n=7)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.143
#
# Starting simulations for mu = 0.5, P = 150
# Simulation 0 for mu=0.5, P=150: HMM_BAC = 0.532, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 100.000, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.5, P=150: HMM_BAC = 0.519, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 49.239, Sparse_Lambda = 100.000, Sparse_Kappa = 3.596
# Simulation 2 for mu=0.5, P=150: HMM_BAC = 0.497, Jump_BAC = 0.983, SparseJump_BAC = 0.994, Jump_Lambda = 49.239, Sparse_Lambda = 100.000, Sparse_Kappa = 1.865
# Simulation 3 for mu=0.5, P=150: HMM_BAC = 0.413, Jump_BAC = 0.639, SparseJump_BAC = 0.697, Jump_Lambda = 49.239, Sparse_Lambda = 3.162, Sparse_Kappa = 3.596
# Simulation 4 for mu=0.5, P=150: HMM_BAC = 0.503, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 2.730
# Simulation 5 for mu=0.5, P=150: HMM_BAC = 0.481, Jump_BAC = 0.502, SparseJump_BAC = 0.590, Jump_Lambda = 0.010, Sparse_Lambda = 1.000, Sparse_Kappa = 1.865
# Simulation 6 for mu=0.5, P=150: HMM_BAC = 0.490, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 49.239, Sparse_Lambda = 100.000, Sparse_Kappa = 1.865
# Simulation 7 for mu=0.5, P=150: HMM_BAC = 0.534, Jump_BAC = 0.530, SparseJump_BAC = 0.620, Jump_Lambda = 0.010, Sparse_Lambda = 0.100, Sparse_Kappa = 1.865
# Simulation 8 for mu=0.5, P=150: HMM_BAC = 0.508, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 3.596
# Simulation 9 for mu=0.5, P=150: HMM_BAC = 0.514, Jump_BAC = 0.606, SparseJump_BAC = 0.707, Jump_Lambda = 17.013, Sparse_Lambda = 3.162, Sparse_Kappa = 3.596
# Finished analysis for mu=0.5, P=150
#   HMM BAC = 0.499 ± 0.033
#   Jump BAC = 0.826 ± 0.213
#   Sparse Jump BAC = 0.861 ± 0.172
#   Jump Lambda: 45.50 ± 38.01 (n=4)
#   Sparse Lambda: 47.07 ± 44.57 (n=5)
#   Sparse Kappa: 2.56 ± 0.93 (n=4)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.0216
#
# Starting simulations for mu = 0.5, P = 300
# Simulation 0 for mu=0.5, P=300: HMM_BAC = 0.504, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 412.463, Sparse_Lambda = 100.000, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.5, P=300: HMM_BAC = 0.516, Jump_BAC = 0.869, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 31.623, Sparse_Kappa = 2.255
# Simulation 2 for mu=0.5, P=300: HMM_BAC = 0.557, Jump_BAC = 0.930, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 100.000, Sparse_Kappa = 2.255
# Simulation 3 for mu=0.5, P=300: HMM_BAC = 0.531, Jump_BAC = 0.741, SparseJump_BAC = 0.885, Jump_Lambda = 142.510, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.5, P=300: HMM_BAC = 0.521, Jump_BAC = 0.996, SparseJump_BAC = 0.548, Jump_Lambda = 142.510, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 5 for mu=0.5, P=300: HMM_BAC = 0.513, Jump_BAC = 0.548, SparseJump_BAC = 0.567, Jump_Lambda = 17.013, Sparse_Lambda = 0.100, Sparse_Kappa = 3.511
# Simulation 6 for mu=0.5, P=300: HMM_BAC = 0.449, Jump_BAC = 0.500, SparseJump_BAC = 0.520, Jump_Lambda = 412.463, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 7 for mu=0.5, P=300: HMM_BAC = 0.488, Jump_BAC = 0.551, SparseJump_BAC = 0.673, Jump_Lambda = 17.013, Sparse_Lambda = 0.100, Sparse_Kappa = 3.511
# Simulation 8 for mu=0.5, P=300: HMM_BAC = 0.495, Jump_BAC = 0.586, SparseJump_BAC = 0.527, Jump_Lambda = 142.510, Sparse_Lambda = 31.623, Sparse_Kappa = 4.766
# Simulation 9 for mu=0.5, P=300: HMM_BAC = 0.516, Jump_BAC = 0.589, SparseJump_BAC = 0.644, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 3.511
# Finished analysis for mu=0.5, P=300
#   HMM BAC = 0.509 ± 0.027
#   Jump BAC = 0.731 ± 0.190
#   Sparse Jump BAC = 0.736 ± 0.199
#   Jump Lambda: 162.07 ± 134.95 (n=4)
#   Sparse Lambda: 34.67 ± 34.90 (n=4)
#   Sparse Kappa: 2.38 ± 1.31 (n=4)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.13

# %%
    # Convert summary results to a DataFrame and save to CSV
    df_results = pd.DataFrame(final_rows)
    print("\nFinal Summary Results:")
    print(df_results, flush=True)
    df_results.to_csv("simulation_results(corr_n10).csv", index=False)

    # Convert raw simulation details to a DataFrame and save to CSV for full transparency
    df_sim_details = pd.DataFrame(simulation_details)
    print("\nRaw Simulation Details (first few rows):")
    print(df_sim_details.head(), flush=True)
    #df_sim_details.to_csv("simulation_simulation_details(corr_n10).csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Convert summary results to a DataFrame and save to CSV
# ----> 2 df_results = pd.DataFrame(final_rows)
#       3 print("\nFinal Summary Results:")
#       4 print(df_results, flush=True)
#
# NameError: name 'final_rows' is not defined

# %%
    # Convert raw simulation details to a DataFrame and save to CSV for full transparency
    df_sim_details = pd.DataFrame(simulation_details)
    print("\nRaw Simulation Details (first few rows):")
    print(df_sim_details.head(), flush=True)
    #df_sim_details.to_csv("simulation_simulation_details(corr_n10).csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Convert raw simulation details to a DataFrame and save to CSV for full transparency
# ----> 2 df_sim_details = pd.DataFrame(simulation_details)
#       3 print("\nRaw Simulation Details (first few rows):")
#       4 print(df_sim_details.head(), flush=True)
#
# NameError: name 'simulation_details' is not defined
