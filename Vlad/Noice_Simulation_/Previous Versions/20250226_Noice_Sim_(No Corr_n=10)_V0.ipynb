# %% [markdown]
# # Simulation Study for Noise Filtering
#
# This is the v0 for the simulation study on the sparse jump model comparison with HMM, to show that SJM is able to filter away noisy data by using the weighting in the algorithm.

# %%
# Load packages
import numpy as np
import pandas as pd
from hmmlearn import hmm
from sklearn.metrics import balanced_accuracy_score, confusion_matrix
from scipy.optimize import linear_sum_assignment
from jumpmodels.sparse_jump import SparseJumpModel    # Sparse JM class
from jumpmodels.jump import JumpModel   
from scipy import stats
from joblib import Parallel, delayed
import multiprocessing
from scipy.stats import wilcoxon

# %% [markdown]
# ## 1. Data Simulation & Utility Functions
# def simulate_data(T, P, mu, random_state=None): """ Simulate data from a 2-state Gaussian HMM with correlation 0.1 between the features

# %%
def simulate_data(T, P, mu, random_state=None):
    """
    Simulate data from a 2-state Gaussian HMM with correlated noise for features beyond
    the first 15 informative features.
    """
    rng = np.random.default_rng(random_state)
    
    # Transition matrix for 2 states
    transmat = np.array([[0.9980, 0.0020],
                         [0.0114, 0.9886]])
    
    # Compute stationary distribution
    eigvals, eigvecs = np.linalg.eig(transmat.T)
    stat = np.real(eigvecs[:, np.isclose(eigvals, 1)])
    stat = stat[:, 0]
    stat = stat / np.sum(stat)
    
    # Generate state sequence
    states = np.zeros(T, dtype=int)
    states[0] = rng.choice(np.arange(2), p=stat)
    for t in range(1, T):
        states[t] = rng.choice(np.arange(2), p=transmat[states[t-1]])
    
    # Define means for each state: first 15 features are informative
    means = np.zeros((2, P))
    if P >= 15:
        means[0, :15] = -mu
        means[1, :15] = mu
    else:
        means[0, :P] = -mu
        means[1, :P] = mu
    
    # Prepare correlated noise for features beyond the first 15
    informative = 15
    if P > informative:
        num_noise = P - informative
        sigma = np.full((num_noise, num_noise), 0.0)
        np.fill_diagonal(sigma, 1.0)
        C = np.linalg.cholesky(sigma)
    else:
        C = None
    
    # Generate observations
    X = np.zeros((T, P))
    for t in range(T):
        # Informative features
        n_inf = min(P, informative)
        X[t, :n_inf] = rng.normal(loc=means[states[t], :n_inf], scale=1.0, size=n_inf)
        # Noise features: correlated noise if P > informative
        if P > informative:
            noise_indep = rng.normal(loc=0.0, scale=1.0, size=P - informative)
            X[t, informative:] = C @ noise_indep
    
    return X, states

# %% [markdown]
# ## 2.Aligning Predicted Labels With True Labels using the Hungarian Algorithm

# %%
def align_labels(true_labels, pred_labels):
    """
    Align predicted labels with true labels using the Hungarian algorithm.
    """
    D = confusion_matrix(true_labels, pred_labels)
    row_ind, col_ind = linear_sum_assignment(-D)
    mapping = {col: row for row, col in zip(row_ind, col_ind)}
    aligned = np.array([mapping[x] for x in pred_labels])
    return aligned

# %% [markdown]
# ## 3. Setting up the function to calcuate the BAC

# %%
def calculate_bac(true_states, pred_states):
    """
    Compute the Balanced Accuracy (BAC) after aligning the predicted state labels.
    """
    aligned_pred = align_labels(true_states, pred_states)
    return balanced_accuracy_score(true_states, aligned_pred)

# %% [markdown]
# ## 4. Functions for model formulation
#
# ### 4.1 HMM With Nystrup (2021) initialization

# %%
def run_hmm(X, n_components=2, random_state=None):
    """
    Fit a Gaussian HMM to the data X.
    """
    model = hmm.GaussianHMM(
        n_components=n_components,
        covariance_type='diag',
        n_iter=100,
        random_state=random_state,
        init_params="mc",
        covars_prior=1.0
    )
    model.startprob_ = np.full(n_components, 1.0 / n_components)
    transmat = np.full((n_components, n_components), 0.05 / (n_components - 1))
    np.fill_diagonal(transmat, 0.95)
    model.transmat_ = transmat
    
    model.fit(X)
    pred_states = model.predict(X)
    return pred_states

# %% [markdown]
# ### 4.2 Normal (Standard) Jump Model with Grid Search over λ

# %%
def run_jump_model_grid_search(X, true_states, n_components=2, random_state=None):
    """
    Perform a grid search over lambda values for the Jump Model.
    
    Returns:
        best_labels: Predicted state sequence for the best lambda.
        best_bac: Best balanced accuracy achieved.
        best_lambda: The lambda value that achieved best_bac.
    """
    lambda_values = np.logspace(-2, 4, 14)
    best_bac = -1
    best_labels = None
    best_lambda = None
    
    for lam in lambda_values:
        model = JumpModel(
            n_components=n_components,
            jump_penalty=lam,
            cont=False,
            max_iter=10,
            random_state=random_state
        )
        model.fit(X)
        labels = model.labels_
        bac = calculate_bac(true_states, labels)
        if bac > best_bac:
            best_bac = bac
            best_labels = labels
            best_lambda = lam
    
    return best_labels, best_bac, best_lambda

# %% [markdown]
# ### 4.3 Sparse Jump Model with Grid Search over λ and kappa

# %%
def run_sparse_jump_model_grid_search(X, true_states, n_components=2, random_state=None):
    """
    Perform a grid search for the best combination of jump_penalty (lambda) and feature selection
    level (kappa) for the Sparse Jump Model (SJM).
    
    Returns:
        best_labels: Predicted state sequence for the best combination.
        best_bac: Best balanced accuracy achieved.
        best_lambda: The lambda value that achieved best_bac.
        best_kappa: The kappa value that achieved best_bac.
    """
    lambdas = np.logspace(-1, 2, 7)
    p = X.shape[1]
    kappas = np.linspace(1, np.sqrt(p), 14)
    
    best_bac = -1
    best_labels = None
    best_lambda = None
    best_kappa = None
    
    for lam in lambdas:
        for kappa in kappas:
            max_feats = kappa**2
            model = SparseJumpModel(
                n_components=n_components,
                jump_penalty=lam,
                cont=False,
                max_feats=max_feats,
                max_iter=10,
                random_state=random_state
            )
            model.fit(X)
            labels = model.labels_
            bac = calculate_bac(true_states, labels)
            if bac > best_bac:
                best_bac = bac
                best_labels = labels
                best_lambda = lam
                best_kappa = kappa
    return best_labels, best_bac, best_lambda, best_kappa

# %% [markdown]
# # 5. Main Execution
#  We split the code into three sections for each model and then combine results at the end.

# %%
def run_one_simulation(sim, T, P, mu):
    """
    Run a single simulation (HMM, Jump, Sparse Jump) and return:
      - BAC scores for HMM, Jump, Sparse Jump
      - Best lambda for Jump Model
      - Best lambda and best kappa for Sparse Jump Model
    """
    # Simulate data
    X, true_states = simulate_data(T, P, mu, random_state=sim)

    # Gaussian HMM
    pred_hmm = run_hmm(X, n_components=2, random_state=sim)
    bac_hmm = calculate_bac(true_states, pred_hmm)

    # Jump Model grid search for hyperparameters
    _, bac_jump, best_lambda_jump = run_jump_model_grid_search(
        X, true_states, n_components=2, random_state=sim
    )

    # Sparse Jump Model grid search for hyperparameters
    _, bac_sparse, best_lambda_sparse, best_kappa_sparse = run_sparse_jump_model_grid_search(
        X, true_states, n_components=2, random_state=sim
    )

    return bac_hmm, bac_jump, bac_sparse, best_lambda_jump, best_lambda_sparse, best_kappa_sparse

if __name__ == "__main__":
    # --- Settings ---
    T = 500
    mu_values = [0.02, 0.05, 0.1, 0.25, 0.5,]
    p_values = [15, 30, 60, 150, 300]
    n_simulations = 10  # Adjust as needed

    # Initialize lists to store summary results and raw simulation details
    final_rows = []          # for summary results per (mu, P) pair
    simulation_details = []  # for raw per-simulation results

    # Detect the number of CPU cores available
    num_cores = multiprocessing.cpu_count()
    print(f"Detected {num_cores} CPU cores.")

    # Main loop over mu and P pairs
    for mu in mu_values:
        for P in p_values:
            print(f"\nStarting simulations for mu = {mu}, P = {P}")

            # Run simulations in parallel (each simulation does its own grid search)
            results = Parallel(n_jobs=num_cores)(
                delayed(run_one_simulation)(sim, T, P, mu) 
                for sim in range(n_simulations)
            )

            # Unpack the results for this (mu, P) pair
            hmm_bac_list      = [res[0] for res in results]
            jump_bac_list     = [res[1] for res in results]
            sparse_bac_list   = [res[2] for res in results]
            lambda_jump_list  = [res[3] for res in results]
            lambda_sparse_list= [res[4] for res in results]
            kappa_sparse_list = [res[5] for res in results]

            # Save the raw simulation results and print each simulation's details
            for sim_idx, res in enumerate(results):
                simulation_details.append({
                    "mu": mu,
                    "P": P,
                    "sim": sim_idx,
                    "HMM_BAC": res[0],
                    "Jump_BAC": res[1],
                    "SparseJump_BAC": res[2],
                    "Jump_Lambda": res[3],
                    "Sparse_Lambda": res[4],
                    "Sparse_Kappa": res[5]
                })
                print(f"Simulation {sim_idx} for mu={mu}, P={P}: "
                      f"HMM_BAC = {res[0]:.3f}, Jump_BAC = {res[1]:.3f}, SparseJump_BAC = {res[2]:.3f}, "
                      f"Jump_Lambda = {res[3]:.3f}, Sparse_Lambda = {res[4]:.3f}, Sparse_Kappa = {res[5]:.3f}")

            # Compute summary statistics for BAC scores
            hmm_mean, hmm_std = np.mean(hmm_bac_list), np.std(hmm_bac_list)
            jump_mean, jump_std = np.mean(jump_bac_list), np.std(jump_bac_list)
            sparse_mean, sparse_std = np.mean(sparse_bac_list), np.std(sparse_bac_list)

            # Compute summary statistics for hyperparameters
            mean_lambda_jump = np.mean(lambda_jump_list)
            std_lambda_jump  = np.std(lambda_jump_list)
            unique_lambda_jump = len(np.unique(lambda_jump_list))
            
            mean_lambda_sparse = np.mean(lambda_sparse_list)
            std_lambda_sparse  = np.std(lambda_sparse_list)
            unique_lambda_sparse = len(np.unique(lambda_sparse_list))
            
            mean_kappa_sparse = np.mean(kappa_sparse_list)
            std_kappa_sparse  = np.std(kappa_sparse_list)
            unique_kappa_sparse = len(np.unique(kappa_sparse_list))
            
            # Compute one-sided Wilcoxon test: test if Sparse Jump BAC is greater than Jump BAC
            stat, pval = wilcoxon(sparse_bac_list, jump_bac_list, alternative="greater")
            if pval < 0.05:
                sparse_str = f"**{sparse_mean:.2f} ± {sparse_std:.2f}**"
            else:
                sparse_str = f"{sparse_mean:.2f} ± {sparse_std:.2f}"
            
            # Append summary results to final_rows
            final_rows.append({
                "mu": mu,
                "P": P,
                "HMM (mean ± std)": f"{hmm_mean:.2f} ± {hmm_std:.2f}",
                "Jump (mean ± std)": f"{jump_mean:.2f} ± {jump_std:.2f}",
                "Sparse Jump (mean ± std)": sparse_str,
                "p-value (Jump vs Sparse, Wilcoxon)": f"{pval:.3g}",
                "Jump Lambda (mean ± std, unique)": f"{mean_lambda_jump:.2f} ± {std_lambda_jump:.2f} (n={unique_lambda_jump})",
                "Sparse Lambda (mean ± std, unique)": f"{mean_lambda_sparse:.2f} ± {std_lambda_sparse:.2f} (n={unique_lambda_sparse})",
                "Sparse Kappa (mean ± std, unique)": f"{mean_kappa_sparse:.2f} ± {std_kappa_sparse:.2f} (n={unique_kappa_sparse})"
            })

            # Print summary for this (mu, P) pair
            print(
                f"Finished analysis for mu={mu}, P={P}\n"
                f"  HMM BAC = {hmm_mean:.3f} ± {hmm_std:.3f}\n"
                f"  Jump BAC = {jump_mean:.3f} ± {jump_std:.3f}\n"
                f"  Sparse Jump BAC = {sparse_mean:.3f} ± {sparse_std:.3f}\n"
                f"  Jump Lambda: {mean_lambda_jump:.2f} ± {std_lambda_jump:.2f} (n={unique_lambda_jump})\n"
                f"  Sparse Lambda: {mean_lambda_sparse:.2f} ± {std_lambda_sparse:.2f} (n={unique_lambda_sparse})\n"
                f"  Sparse Kappa: {mean_kappa_sparse:.2f} ± {std_kappa_sparse:.2f} (n={unique_kappa_sparse})\n"
                f"  p-value (Jump vs Sparse, Wilcoxon) = {pval:.3g}"
            )
# Out:
# Detected 16 CPU cores.
#
# Starting simulations for mu = 0.02, P = 15
# Simulation 0 for mu=0.02, P=15: HMM_BAC = 0.552, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.02, P=15: HMM_BAC = 0.563, Jump_BAC = 0.513, SparseJump_BAC = 0.547, Jump_Lambda = 0.010, Sparse_Lambda = 0.316, Sparse_Kappa = 1.000
# Simulation 2 for mu=0.02, P=15: HMM_BAC = 0.437, Jump_BAC = 0.518, SparseJump_BAC = 0.830, Jump_Lambda = 0.242, Sparse_Lambda = 10.000, Sparse_Kappa = 2.326
# Simulation 3 for mu=0.02, P=15: HMM_BAC = 0.417, Jump_BAC = 0.542, SparseJump_BAC = 0.664, Jump_Lambda = 0.702, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.02, P=15: HMM_BAC = 0.453, Jump_BAC = 0.566, SparseJump_BAC = 0.746, Jump_Lambda = 0.702, Sparse_Lambda = 10.000, Sparse_Kappa = 1.663
# Simulation 5 for mu=0.02, P=15: HMM_BAC = 0.400, Jump_BAC = 0.557, SparseJump_BAC = 0.748, Jump_Lambda = 0.702, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 6 for mu=0.02, P=15: HMM_BAC = 0.599, Jump_BAC = 0.668, SparseJump_BAC = 0.547, Jump_Lambda = 2.031, Sparse_Lambda = 0.316, Sparse_Kappa = 1.000
# Simulation 7 for mu=0.02, P=15: HMM_BAC = 0.496, Jump_BAC = 0.980, SparseJump_BAC = 0.842, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 8 for mu=0.02, P=15: HMM_BAC = 0.557, Jump_BAC = 0.545, SparseJump_BAC = 0.529, Jump_Lambda = 0.702, Sparse_Lambda = 1.000, Sparse_Kappa = 1.442
# Simulation 9 for mu=0.02, P=15: HMM_BAC = 0.314, Jump_BAC = 0.833, SparseJump_BAC = 0.975, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Finished analysis for mu=0.02, P=15
#   HMM BAC = 0.479 ± 0.085
#   Jump BAC = 0.672 ± 0.183
#   Sparse Jump BAC = 0.743 ± 0.163
#   Jump Lambda: 6.22 ± 14.43 (n=6)
#   Sparse Lambda: 7.96 ± 8.88 (n=5)
#   Sparse Kappa: 1.24 ± 0.42 (n=4)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.0549
#
# Starting simulations for mu = 0.02, P = 30
# Simulation 0 for mu=0.02, P=30: HMM_BAC = 0.622, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.02, P=30: HMM_BAC = 0.477, Jump_BAC = 0.524, SparseJump_BAC = 0.548, Jump_Lambda = 0.029, Sparse_Lambda = 3.162, Sparse_Kappa = 3.411
# Simulation 2 for mu=0.02, P=30: HMM_BAC = 0.571, Jump_BAC = 0.583, SparseJump_BAC = 0.541, Jump_Lambda = 0.702, Sparse_Lambda = 1.000, Sparse_Kappa = 1.000
# Simulation 3 for mu=0.02, P=30: HMM_BAC = 0.699, Jump_BAC = 0.566, SparseJump_BAC = 0.661, Jump_Lambda = 0.242, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.02, P=30: HMM_BAC = 0.500, Jump_BAC = 0.538, SparseJump_BAC = 0.629, Jump_Lambda = 0.242, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 5 for mu=0.02, P=30: HMM_BAC = 0.624, Jump_BAC = 0.564, SparseJump_BAC = 0.597, Jump_Lambda = 0.010, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 6 for mu=0.02, P=30: HMM_BAC = 0.540, Jump_BAC = 0.971, SparseJump_BAC = 0.873, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.033
# Simulation 7 for mu=0.02, P=30: HMM_BAC = 0.537, Jump_BAC = 0.745, SparseJump_BAC = 0.552, Jump_Lambda = 2.031, Sparse_Lambda = 0.316, Sparse_Kappa = 1.344
# Simulation 8 for mu=0.02, P=30: HMM_BAC = 0.583, Jump_BAC = 0.523, SparseJump_BAC = 0.579, Jump_Lambda = 0.084, Sparse_Lambda = 3.162, Sparse_Kappa = 4.100
# Simulation 9 for mu=0.02, P=30: HMM_BAC = 0.390, Jump_BAC = 0.587, SparseJump_BAC = 0.614, Jump_Lambda = 0.702, Sparse_Lambda = 0.100, Sparse_Kappa = 1.000
# Finished analysis for mu=0.02, P=30
#   HMM BAC = 0.554 ± 0.082
#   Jump BAC = 0.660 ± 0.173
#   Sparse Jump BAC = 0.659 ± 0.146
#   Jump Lambda: 2.69 ± 5.07 (n=8)
#   Sparse Lambda: 7.25 ± 8.97 (n=6)
#   Sparse Kappa: 1.69 ± 1.09 (n=5)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.429
#
# Starting simulations for mu = 0.02, P = 60
# Simulation 0 for mu=0.02, P=60: HMM_BAC = 0.586, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.02, P=60: HMM_BAC = 0.458, Jump_BAC = 0.671, SparseJump_BAC = 0.686, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 2.038
# Simulation 2 for mu=0.02, P=60: HMM_BAC = 0.504, Jump_BAC = 0.962, SparseJump_BAC = 0.982, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 3.076
# Simulation 3 for mu=0.02, P=60: HMM_BAC = 0.347, Jump_BAC = 0.500, SparseJump_BAC = 0.623, Jump_Lambda = 49.239, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.02, P=60: HMM_BAC = 0.559, Jump_BAC = 0.556, SparseJump_BAC = 0.538, Jump_Lambda = 0.702, Sparse_Lambda = 3.162, Sparse_Kappa = 1.519
# Simulation 5 for mu=0.02, P=60: HMM_BAC = 0.506, Jump_BAC = 0.562, SparseJump_BAC = 0.568, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 6 for mu=0.02, P=60: HMM_BAC = 0.496, Jump_BAC = 0.853, SparseJump_BAC = 0.573, Jump_Lambda = 17.013, Sparse_Lambda = 3.162, Sparse_Kappa = 3.595
# Simulation 7 for mu=0.02, P=60: HMM_BAC = 0.555, Jump_BAC = 0.810, SparseJump_BAC = 0.705, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 1.519
# Simulation 8 for mu=0.02, P=60: HMM_BAC = 0.517, Jump_BAC = 0.503, SparseJump_BAC = 0.789, Jump_Lambda = 0.702, Sparse_Lambda = 10.000, Sparse_Kappa = 3.595
# Simulation 9 for mu=0.02, P=60: HMM_BAC = 0.577, Jump_BAC = 0.986, SparseJump_BAC = 0.989, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 2.557
# Finished analysis for mu=0.02, P=60
#   HMM BAC = 0.511 ± 0.066
#   Jump BAC = 0.740 ± 0.195
#   Sparse Jump BAC = 0.745 ± 0.175
#   Jump Lambda: 17.97 ± 16.88 (n=4)
#   Sparse Lambda: 10.91 ± 10.77 (n=3)
#   Sparse Kappa: 2.09 ± 1.00 (n=6)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.297
#
# Starting simulations for mu = 0.02, P = 150
# Simulation 0 for mu=0.02, P=150: HMM_BAC = 0.526, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 100.000, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.02, P=150: HMM_BAC = 0.425, Jump_BAC = 0.573, SparseJump_BAC = 0.540, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 2 for mu=0.02, P=150: HMM_BAC = 0.546, Jump_BAC = 0.586, SparseJump_BAC = 0.560, Jump_Lambda = 2.031, Sparse_Lambda = 0.100, Sparse_Kappa = 1.000
# Simulation 3 for mu=0.02, P=150: HMM_BAC = 0.666, Jump_BAC = 0.500, SparseJump_BAC = 0.836, Jump_Lambda = 142.510, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.02, P=150: HMM_BAC = 0.498, Jump_BAC = 0.799, SparseJump_BAC = 0.555, Jump_Lambda = 49.239, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 5 for mu=0.02, P=150: HMM_BAC = 0.578, Jump_BAC = 0.596, SparseJump_BAC = 0.553, Jump_Lambda = 0.084, Sparse_Lambda = 1.000, Sparse_Kappa = 1.000
# Simulation 6 for mu=0.02, P=150: HMM_BAC = 0.528, Jump_BAC = 0.532, SparseJump_BAC = 0.565, Jump_Lambda = 0.084, Sparse_Lambda = 10.000, Sparse_Kappa = 1.865
# Simulation 7 for mu=0.02, P=150: HMM_BAC = 0.494, Jump_BAC = 0.618, SparseJump_BAC = 0.639, Jump_Lambda = 0.702, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 8 for mu=0.02, P=150: HMM_BAC = 0.557, Jump_BAC = 0.515, SparseJump_BAC = 0.679, Jump_Lambda = 2.031, Sparse_Lambda = 31.623, Sparse_Kappa = 2.730
# Simulation 9 for mu=0.02, P=150: HMM_BAC = 0.807, Jump_BAC = 0.544, SparseJump_BAC = 0.709, Jump_Lambda = 0.084, Sparse_Lambda = 0.100, Sparse_Kappa = 3.596
# Finished analysis for mu=0.02, P=150
#   HMM BAC = 0.563 ± 0.101
#   Jump BAC = 0.626 ± 0.148
#   Sparse Jump BAC = 0.664 ± 0.143
#   Jump Lambda: 34.13 ± 56.04 (n=5)
#   Sparse Lambda: 19.08 ± 29.29 (n=6)
#   Sparse Kappa: 1.52 ± 0.88 (n=4)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.339
#
# Starting simulations for mu = 0.02, P = 300
# Simulation 0 for mu=0.02, P=300: HMM_BAC = 0.598, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 100.000, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.02, P=300: HMM_BAC = 0.488, Jump_BAC = 0.579, SparseJump_BAC = 0.553, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 6.022
# Simulation 2 for mu=0.02, P=300: HMM_BAC = 0.500, Jump_BAC = 0.691, SparseJump_BAC = 0.570, Jump_Lambda = 17.013, Sparse_Lambda = 0.100, Sparse_Kappa = 1.000
# Simulation 3 for mu=0.02, P=300: HMM_BAC = 0.615, Jump_BAC = 0.824, SparseJump_BAC = 0.940, Jump_Lambda = 142.510, Sparse_Lambda = 10.000, Sparse_Kappa = 7.277
# Simulation 4 for mu=0.02, P=300: HMM_BAC = 0.556, Jump_BAC = 0.559, SparseJump_BAC = 0.564, Jump_Lambda = 0.702, Sparse_Lambda = 10.000, Sparse_Kappa = 2.255
# Simulation 5 for mu=0.02, P=300: HMM_BAC = 0.508, Jump_BAC = 0.652, SparseJump_BAC = 0.579, Jump_Lambda = 17.013, Sparse_Lambda = 3.162, Sparse_Kappa = 3.511
# Simulation 6 for mu=0.02, P=300: HMM_BAC = 0.525, Jump_BAC = 0.649, SparseJump_BAC = 0.672, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 2.255
# Simulation 7 for mu=0.02, P=300: HMM_BAC = 0.533, Jump_BAC = 0.972, SparseJump_BAC = 0.967, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 2.255
# Simulation 8 for mu=0.02, P=300: HMM_BAC = 0.505, Jump_BAC = 0.748, SparseJump_BAC = 0.703, Jump_Lambda = 142.510, Sparse_Lambda = 100.000, Sparse_Kappa = 2.255
# Simulation 9 for mu=0.02, P=300: HMM_BAC = 0.478, Jump_BAC = 0.758, SparseJump_BAC = 0.778, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 3.511
# Finished analysis for mu=0.02, P=300
#   HMM BAC = 0.531 ± 0.044
#   Jump BAC = 0.743 ± 0.143
#   Sparse Jump BAC = 0.733 ± 0.169
#   Jump Lambda: 61.20 ± 55.97 (n=5)
#   Sparse Lambda: 32.13 ± 35.91 (n=5)
#   Sparse Kappa: 3.13 ± 1.95 (n=5)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.779
#
# Starting simulations for mu = 0.05, P = 15
# Simulation 0 for mu=0.05, P=15: HMM_BAC = 0.552, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.05, P=15: HMM_BAC = 0.539, Jump_BAC = 0.716, SparseJump_BAC = 0.526, Jump_Lambda = 5.878, Sparse_Lambda = 0.100, Sparse_Kappa = 1.000
# Simulation 2 for mu=0.05, P=15: HMM_BAC = 0.433, Jump_BAC = 0.672, SparseJump_BAC = 0.837, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 2.547
# Simulation 3 for mu=0.05, P=15: HMM_BAC = 0.421, Jump_BAC = 0.559, SparseJump_BAC = 0.664, Jump_Lambda = 0.029, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.05, P=15: HMM_BAC = 0.453, Jump_BAC = 0.563, SparseJump_BAC = 0.592, Jump_Lambda = 0.702, Sparse_Lambda = 3.162, Sparse_Kappa = 1.442
# Simulation 5 for mu=0.05, P=15: HMM_BAC = 0.400, Jump_BAC = 0.570, SparseJump_BAC = 0.547, Jump_Lambda = 0.702, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 6 for mu=0.05, P=15: HMM_BAC = 0.601, Jump_BAC = 0.701, SparseJump_BAC = 0.557, Jump_Lambda = 2.031, Sparse_Lambda = 0.316, Sparse_Kappa = 1.000
# Simulation 7 for mu=0.05, P=15: HMM_BAC = 0.562, Jump_BAC = 0.997, SparseJump_BAC = 0.993, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 8 for mu=0.05, P=15: HMM_BAC = 0.555, Jump_BAC = 0.690, SparseJump_BAC = 0.593, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 9 for mu=0.05, P=15: HMM_BAC = 0.323, Jump_BAC = 0.833, SparseJump_BAC = 0.917, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.663
# Finished analysis for mu=0.05, P=15
#   HMM BAC = 0.484 ± 0.085
#   Jump BAC = 0.730 ± 0.156
#   Sparse Jump BAC = 0.723 ± 0.183
#   Jump Lambda: 7.44 ± 14.10 (n=5)
#   Sparse Lambda: 7.47 ± 8.84 (n=5)
#   Sparse Kappa: 1.27 ± 0.48 (n=4)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.571
#
# Starting simulations for mu = 0.05, P = 30
# Simulation 0 for mu=0.05, P=30: HMM_BAC = 0.622, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.05, P=30: HMM_BAC = 0.481, Jump_BAC = 0.892, SparseJump_BAC = 0.832, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 2 for mu=0.05, P=30: HMM_BAC = 0.609, Jump_BAC = 0.822, SparseJump_BAC = 0.933, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.066
# Simulation 3 for mu=0.05, P=30: HMM_BAC = 0.354, Jump_BAC = 0.568, SparseJump_BAC = 0.555, Jump_Lambda = 0.242, Sparse_Lambda = 0.316, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.05, P=30: HMM_BAC = 0.503, Jump_BAC = 0.535, SparseJump_BAC = 0.563, Jump_Lambda = 0.242, Sparse_Lambda = 1.000, Sparse_Kappa = 1.344
# Simulation 5 for mu=0.05, P=30: HMM_BAC = 0.489, Jump_BAC = 0.580, SparseJump_BAC = 0.597, Jump_Lambda = 0.029, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 6 for mu=0.05, P=30: HMM_BAC = 0.538, Jump_BAC = 0.873, SparseJump_BAC = 0.948, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 3.066
# Simulation 7 for mu=0.05, P=30: HMM_BAC = 0.513, Jump_BAC = 0.745, SparseJump_BAC = 0.604, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 8 for mu=0.05, P=30: HMM_BAC = 0.532, Jump_BAC = 0.531, SparseJump_BAC = 0.550, Jump_Lambda = 0.010, Sparse_Lambda = 0.316, Sparse_Kappa = 1.000
# Simulation 9 for mu=0.05, P=30: HMM_BAC = 0.391, Jump_BAC = 0.575, SparseJump_BAC = 0.863, Jump_Lambda = 0.702, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Finished analysis for mu=0.05, P=30
#   HMM BAC = 0.503 ± 0.079
#   Jump BAC = 0.712 ± 0.166
#   Sparse Jump BAC = 0.745 ± 0.177
#   Jump Lambda: 4.90 ± 6.42 (n=7)
#   Sparse Lambda: 8.64 ± 8.74 (n=5)
#   Sparse Kappa: 1.45 ± 0.82 (n=3)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.157
#
# Starting simulations for mu = 0.05, P = 60
# Simulation 0 for mu=0.05, P=60: HMM_BAC = 0.586, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.05, P=60: HMM_BAC = 0.480, Jump_BAC = 0.671, SparseJump_BAC = 0.542, Jump_Lambda = 17.013, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 2 for mu=0.05, P=60: HMM_BAC = 0.499, Jump_BAC = 0.665, SparseJump_BAC = 0.602, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 2.557
# Simulation 3 for mu=0.05, P=60: HMM_BAC = 0.346, Jump_BAC = 0.500, SparseJump_BAC = 0.512, Jump_Lambda = 49.239, Sparse_Lambda = 3.162, Sparse_Kappa = 1.519
# Simulation 4 for mu=0.05, P=60: HMM_BAC = 0.570, Jump_BAC = 0.614, SparseJump_BAC = 0.894, Jump_Lambda = 2.031, Sparse_Lambda = 31.623, Sparse_Kappa = 3.076
# Simulation 5 for mu=0.05, P=60: HMM_BAC = 0.511, Jump_BAC = 0.577, SparseJump_BAC = 0.568, Jump_Lambda = 0.702, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 6 for mu=0.05, P=60: HMM_BAC = 0.494, Jump_BAC = 0.968, SparseJump_BAC = 0.573, Jump_Lambda = 17.013, Sparse_Lambda = 3.162, Sparse_Kappa = 3.595
# Simulation 7 for mu=0.05, P=60: HMM_BAC = 0.555, Jump_BAC = 0.810, SparseJump_BAC = 0.712, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 2.038
# Simulation 8 for mu=0.05, P=60: HMM_BAC = 0.537, Jump_BAC = 0.529, SparseJump_BAC = 0.656, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.076
# Simulation 9 for mu=0.05, P=60: HMM_BAC = 0.650, Jump_BAC = 0.971, SparseJump_BAC = 0.989, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.038
# Finished analysis for mu=0.05, P=60
#   HMM BAC = 0.523 ± 0.076
#   Jump BAC = 0.731 ± 0.182
#   Sparse Jump BAC = 0.705 ± 0.178
#   Jump Lambda: 15.87 ± 17.47 (n=5)
#   Sparse Lambda: 10.22 ± 11.02 (n=3)
#   Sparse Kappa: 2.09 ± 0.91 (n=6)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.661
#
# Starting simulations for mu = 0.05, P = 150
# Simulation 0 for mu=0.05, P=150: HMM_BAC = 0.526, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 100.000, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.05, P=150: HMM_BAC = 0.604, Jump_BAC = 0.578, SparseJump_BAC = 0.590, Jump_Lambda = 2.031, Sparse_Lambda = 0.100, Sparse_Kappa = 2.730
# Simulation 2 for mu=0.05, P=150: HMM_BAC = 0.533, Jump_BAC = 0.565, SparseJump_BAC = 0.554, Jump_Lambda = 0.242, Sparse_Lambda = 0.100, Sparse_Kappa = 1.000
# Simulation 3 for mu=0.05, P=150: HMM_BAC = 0.666, Jump_BAC = 0.500, SparseJump_BAC = 0.836, Jump_Lambda = 142.510, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.05, P=150: HMM_BAC = 0.506, Jump_BAC = 0.799, SparseJump_BAC = 0.550, Jump_Lambda = 49.239, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 5 for mu=0.05, P=150: HMM_BAC = 0.572, Jump_BAC = 0.596, SparseJump_BAC = 0.539, Jump_Lambda = 0.084, Sparse_Lambda = 3.162, Sparse_Kappa = 1.865
# Simulation 6 for mu=0.05, P=150: HMM_BAC = 0.593, Jump_BAC = 0.551, SparseJump_BAC = 0.571, Jump_Lambda = 0.702, Sparse_Lambda = 3.162, Sparse_Kappa = 1.865
# Simulation 7 for mu=0.05, P=150: HMM_BAC = 0.464, Jump_BAC = 0.670, SparseJump_BAC = 0.639, Jump_Lambda = 0.702, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 8 for mu=0.05, P=150: HMM_BAC = 0.500, Jump_BAC = 0.531, SparseJump_BAC = 0.677, Jump_Lambda = 2.031, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 9 for mu=0.05, P=150: HMM_BAC = 0.500, Jump_BAC = 0.500, SparseJump_BAC = 0.559, Jump_Lambda = 142.510, Sparse_Lambda = 1.000, Sparse_Kappa = 1.865
# Finished analysis for mu=0.05, P=150
#   HMM BAC = 0.546 ± 0.058
#   Jump BAC = 0.629 ± 0.150
#   Sparse Jump BAC = 0.652 ± 0.144
#   Jump Lambda: 48.26 ± 63.30 (n=6)
#   Sparse Lambda: 18.39 ± 29.58 (n=6)
#   Sparse Kappa: 1.43 ± 0.58 (n=3)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.297
#
# Starting simulations for mu = 0.05, P = 300
# Simulation 0 for mu=0.05, P=300: HMM_BAC = 0.598, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 100.000, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.05, P=300: HMM_BAC = 0.514, Jump_BAC = 0.579, SparseJump_BAC = 0.553, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 6.022
# Simulation 2 for mu=0.05, P=300: HMM_BAC = 0.521, Jump_BAC = 0.691, SparseJump_BAC = 0.570, Jump_Lambda = 17.013, Sparse_Lambda = 0.316, Sparse_Kappa = 6.022
# Simulation 3 for mu=0.05, P=300: HMM_BAC = 0.415, Jump_BAC = 0.824, SparseJump_BAC = 0.940, Jump_Lambda = 142.510, Sparse_Lambda = 10.000, Sparse_Kappa = 7.277
# Simulation 4 for mu=0.05, P=300: HMM_BAC = 0.564, Jump_BAC = 0.563, SparseJump_BAC = 0.564, Jump_Lambda = 0.029, Sparse_Lambda = 10.000, Sparse_Kappa = 2.255
# Simulation 5 for mu=0.05, P=300: HMM_BAC = 0.498, Jump_BAC = 0.652, SparseJump_BAC = 0.558, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 6 for mu=0.05, P=300: HMM_BAC = 0.516, Jump_BAC = 0.649, SparseJump_BAC = 0.672, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 2.255
# Simulation 7 for mu=0.05, P=300: HMM_BAC = 0.530, Jump_BAC = 0.972, SparseJump_BAC = 0.967, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 2.255
# Simulation 8 for mu=0.05, P=300: HMM_BAC = 0.519, Jump_BAC = 0.677, SparseJump_BAC = 0.711, Jump_Lambda = 49.239, Sparse_Lambda = 100.000, Sparse_Kappa = 4.766
# Simulation 9 for mu=0.05, P=300: HMM_BAC = 0.400, Jump_BAC = 0.758, SparseJump_BAC = 0.778, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 3.511
# Finished analysis for mu=0.05, P=300
#   HMM BAC = 0.508 ± 0.057
#   Jump BAC = 0.737 ± 0.144
#   Sparse Jump BAC = 0.731 ± 0.171
#   Jump Lambda: 48.58 ± 50.16 (n=5)
#   Sparse Lambda: 32.83 ± 35.40 (n=5)
#   Sparse Kappa: 3.64 ± 2.13 (n=6)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.524
#
# Starting simulations for mu = 0.1, P = 15
# Simulation 0 for mu=0.1, P=15: HMM_BAC = 0.552, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.1, P=15: HMM_BAC = 0.456, Jump_BAC = 0.720, SparseJump_BAC = 0.515, Jump_Lambda = 5.878, Sparse_Lambda = 1.000, Sparse_Kappa = 1.000
# Simulation 2 for mu=0.1, P=15: HMM_BAC = 0.423, Jump_BAC = 0.980, SparseJump_BAC = 0.980, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.105
# Simulation 3 for mu=0.1, P=15: HMM_BAC = 0.441, Jump_BAC = 0.665, SparseJump_BAC = 0.604, Jump_Lambda = 0.702, Sparse_Lambda = 0.100, Sparse_Kappa = 1.221
# Simulation 4 for mu=0.1, P=15: HMM_BAC = 0.852, Jump_BAC = 0.992, SparseJump_BAC = 0.903, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.768
# Simulation 5 for mu=0.1, P=15: HMM_BAC = 0.551, Jump_BAC = 0.585, SparseJump_BAC = 0.511, Jump_Lambda = 0.242, Sparse_Lambda = 1.000, Sparse_Kappa = 1.000
# Simulation 6 for mu=0.1, P=15: HMM_BAC = 0.555, Jump_BAC = 0.769, SparseJump_BAC = 0.769, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.326
# Simulation 7 for mu=0.1, P=15: HMM_BAC = 0.494, Jump_BAC = 0.980, SparseJump_BAC = 0.993, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 8 for mu=0.1, P=15: HMM_BAC = 0.995, Jump_BAC = 0.995, SparseJump_BAC = 0.995, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 2.547
# Simulation 9 for mu=0.1, P=15: HMM_BAC = 0.320, Jump_BAC = 0.833, SparseJump_BAC = 0.917, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.663
# Finished analysis for mu=0.1, P=15
#   HMM BAC = 0.564 ± 0.195
#   Jump BAC = 0.852 ± 0.150
#   Sparse Jump BAC = 0.819 ± 0.193
#   Jump Lambda: 8.75 ± 13.68 (n=5)
#   Sparse Lambda: 8.69 ± 8.70 (n=5)
#   Sparse Kappa: 1.66 ± 0.68 (n=7)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.876
#
# Starting simulations for mu = 0.1, P = 30
# Simulation 0 for mu=0.1, P=30: HMM_BAC = 0.622, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.1, P=30: HMM_BAC = 0.497, Jump_BAC = 0.992, SparseJump_BAC = 0.996, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 2.722
# Simulation 2 for mu=0.1, P=30: HMM_BAC = 0.791, Jump_BAC = 0.583, SparseJump_BAC = 0.559, Jump_Lambda = 5.878, Sparse_Lambda = 0.100, Sparse_Kappa = 3.411
# Simulation 3 for mu=0.1, P=30: HMM_BAC = 0.358, Jump_BAC = 0.570, SparseJump_BAC = 0.555, Jump_Lambda = 0.029, Sparse_Lambda = 0.316, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.1, P=30: HMM_BAC = 0.537, Jump_BAC = 0.944, SparseJump_BAC = 0.940, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 2.378
# Simulation 5 for mu=0.1, P=30: HMM_BAC = 0.492, Jump_BAC = 0.782, SparseJump_BAC = 0.597, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 6 for mu=0.1, P=30: HMM_BAC = 0.331, Jump_BAC = 0.987, SparseJump_BAC = 0.990, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.033
# Simulation 7 for mu=0.1, P=30: HMM_BAC = 0.590, Jump_BAC = 0.745, SparseJump_BAC = 0.604, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 8 for mu=0.1, P=30: HMM_BAC = 0.495, Jump_BAC = 0.762, SparseJump_BAC = 0.578, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 1.000
# Simulation 9 for mu=0.1, P=30: HMM_BAC = 0.350, Jump_BAC = 0.614, SparseJump_BAC = 0.863, Jump_Lambda = 0.702, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Finished analysis for mu=0.1, P=30
#   HMM BAC = 0.506 ± 0.134
#   Jump BAC = 0.798 ± 0.165
#   Sparse Jump BAC = 0.768 ± 0.194
#   Jump Lambda: 6.96 ± 6.82 (n=5)
#   Sparse Lambda: 8.84 ± 8.60 (n=5)
#   Sparse Kappa: 1.65 ± 0.86 (n=5)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.87
#
# Starting simulations for mu = 0.1, P = 60
# Simulation 0 for mu=0.1, P=60: HMM_BAC = 0.586, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.1, P=60: HMM_BAC = 0.515, Jump_BAC = 0.861, SparseJump_BAC = 0.956, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 4.114
# Simulation 2 for mu=0.1, P=60: HMM_BAC = 0.467, Jump_BAC = 0.962, SparseJump_BAC = 0.982, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 2.038
# Simulation 3 for mu=0.1, P=60: HMM_BAC = 0.346, Jump_BAC = 0.630, SparseJump_BAC = 0.512, Jump_Lambda = 0.084, Sparse_Lambda = 3.162, Sparse_Kappa = 1.519
# Simulation 4 for mu=0.1, P=60: HMM_BAC = 0.651, Jump_BAC = 0.961, SparseJump_BAC = 0.959, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.595
# Simulation 5 for mu=0.1, P=60: HMM_BAC = 0.517, Jump_BAC = 0.600, SparseJump_BAC = 0.588, Jump_Lambda = 0.702, Sparse_Lambda = 0.100, Sparse_Kappa = 1.000
# Simulation 6 for mu=0.1, P=60: HMM_BAC = 0.452, Jump_BAC = 0.963, SparseJump_BAC = 0.888, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 2.038
# Simulation 7 for mu=0.1, P=60: HMM_BAC = 0.442, Jump_BAC = 0.853, SparseJump_BAC = 0.712, Jump_Lambda = 17.013, Sparse_Lambda = 3.162, Sparse_Kappa = 2.038
# Simulation 8 for mu=0.1, P=60: HMM_BAC = 0.545, Jump_BAC = 0.544, SparseJump_BAC = 0.845, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 3.595
# Simulation 9 for mu=0.1, P=60: HMM_BAC = 0.548, Jump_BAC = 0.971, SparseJump_BAC = 0.989, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.557
# Finished analysis for mu=0.1, P=60
#   HMM BAC = 0.507 ± 0.081
#   Jump BAC = 0.835 ± 0.167
#   Sparse Jump BAC = 0.843 ± 0.169
#   Jump Lambda: 13.19 ± 13.85 (n=6)
#   Sparse Lambda: 11.97 ± 10.43 (n=4)
#   Sparse Kappa: 2.35 ± 1.04 (n=6)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.524
#
# Starting simulations for mu = 0.1, P = 150
# Simulation 0 for mu=0.1, P=150: HMM_BAC = 0.526, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 100.000, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.1, P=150: HMM_BAC = 0.552, Jump_BAC = 0.631, SparseJump_BAC = 0.568, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 2 for mu=0.1, P=150: HMM_BAC = 0.527, Jump_BAC = 0.580, SparseJump_BAC = 0.544, Jump_Lambda = 2.031, Sparse_Lambda = 1.000, Sparse_Kappa = 1.000
# Simulation 3 for mu=0.1, P=150: HMM_BAC = 0.667, Jump_BAC = 0.500, SparseJump_BAC = 0.836, Jump_Lambda = 142.510, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.1, P=150: HMM_BAC = 0.499, Jump_BAC = 0.824, SparseJump_BAC = 0.540, Jump_Lambda = 49.239, Sparse_Lambda = 3.162, Sparse_Kappa = 3.596
# Simulation 5 for mu=0.1, P=150: HMM_BAC = 0.430, Jump_BAC = 0.567, SparseJump_BAC = 0.553, Jump_Lambda = 0.029, Sparse_Lambda = 1.000, Sparse_Kappa = 1.000
# Simulation 6 for mu=0.1, P=150: HMM_BAC = 0.564, Jump_BAC = 0.527, SparseJump_BAC = 0.571, Jump_Lambda = 0.084, Sparse_Lambda = 3.162, Sparse_Kappa = 1.865
# Simulation 7 for mu=0.1, P=150: HMM_BAC = 0.419, Jump_BAC = 0.794, SparseJump_BAC = 0.794, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.865
# Simulation 8 for mu=0.1, P=150: HMM_BAC = 0.567, Jump_BAC = 0.557, SparseJump_BAC = 0.684, Jump_Lambda = 0.242, Sparse_Lambda = 31.623, Sparse_Kappa = 2.730
# Simulation 9 for mu=0.1, P=150: HMM_BAC = 0.492, Jump_BAC = 0.500, SparseJump_BAC = 0.634, Jump_Lambda = 142.510, Sparse_Lambda = 3.162, Sparse_Kappa = 5.326
# Finished analysis for mu=0.1, P=150
#   HMM BAC = 0.524 ± 0.068
#   Jump BAC = 0.648 ± 0.159
#   Sparse Jump BAC = 0.673 ± 0.148
#   Jump Lambda: 53.04 ± 61.36 (n=6)
#   Sparse Lambda: 21.64 ± 29.07 (n=5)
#   Sparse Kappa: 2.04 ± 1.38 (n=5)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.288
#
# Starting simulations for mu = 0.1, P = 300
# Simulation 0 for mu=0.1, P=300: HMM_BAC = 0.598, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 100.000, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.1, P=300: HMM_BAC = 0.504, Jump_BAC = 0.581, SparseJump_BAC = 0.540, Jump_Lambda = 2.031, Sparse_Lambda = 0.100, Sparse_Kappa = 1.000
# Simulation 2 for mu=0.1, P=300: HMM_BAC = 0.547, Jump_BAC = 0.576, SparseJump_BAC = 0.519, Jump_Lambda = 0.010, Sparse_Lambda = 1.000, Sparse_Kappa = 1.000
# Simulation 3 for mu=0.1, P=300: HMM_BAC = 0.420, Jump_BAC = 0.838, SparseJump_BAC = 0.940, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 6.022
# Simulation 4 for mu=0.1, P=300: HMM_BAC = 0.525, Jump_BAC = 0.532, SparseJump_BAC = 0.542, Jump_Lambda = 0.010, Sparse_Lambda = 1.000, Sparse_Kappa = 2.255
# Simulation 5 for mu=0.1, P=300: HMM_BAC = 0.595, Jump_BAC = 0.785, SparseJump_BAC = 0.787, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 6 for mu=0.1, P=300: HMM_BAC = 0.534, Jump_BAC = 0.649, SparseJump_BAC = 0.612, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 2.255
# Simulation 7 for mu=0.1, P=300: HMM_BAC = 0.545, Jump_BAC = 0.972, SparseJump_BAC = 0.967, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 2.255
# Simulation 8 for mu=0.1, P=300: HMM_BAC = 0.499, Jump_BAC = 0.729, SparseJump_BAC = 0.740, Jump_Lambda = 49.239, Sparse_Lambda = 100.000, Sparse_Kappa = 3.511
# Simulation 9 for mu=0.1, P=300: HMM_BAC = 0.398, Jump_BAC = 0.758, SparseJump_BAC = 0.778, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 3.511
# Finished analysis for mu=0.1, P=300
#   HMM BAC = 0.516 ± 0.062
#   Jump BAC = 0.742 ± 0.154
#   Sparse Jump BAC = 0.742 ± 0.175
#   Jump Lambda: 36.06 ± 41.60 (n=5)
#   Sparse Lambda: 33.86 ± 35.55 (n=5)
#   Sparse Kappa: 2.38 ± 1.53 (n=4)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.524
#
# Starting simulations for mu = 0.25, P = 15
# Simulation 0 for mu=0.25, P=15: HMM_BAC = 0.552, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.25, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 3.873
# Simulation 2 for mu=0.25, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 3.431
# Simulation 3 for mu=0.25, P=15: HMM_BAC = 0.885, Jump_BAC = 0.999, SparseJump_BAC = 0.999, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.221
# Simulation 4 for mu=0.25, P=15: HMM_BAC = 0.997, Jump_BAC = 0.997, SparseJump_BAC = 0.997, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.768
# Simulation 5 for mu=0.25, P=15: HMM_BAC = 0.998, Jump_BAC = 0.999, SparseJump_BAC = 0.998, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.210
# Simulation 6 for mu=0.25, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.652
# Simulation 7 for mu=0.25, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 0.994, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.884
# Simulation 8 for mu=0.25, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 2.989
# Simulation 9 for mu=0.25, P=15: HMM_BAC = 0.376, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.663
# Finished analysis for mu=0.25, P=15
#   HMM BAC = 0.881 ± 0.215
#   Jump BAC = 1.000 ± 0.001
#   Sparse Jump BAC = 0.999 ± 0.002
#   Jump Lambda: 10.21 ± 13.01 (n=2)
#   Sparse Lambda: 10.11 ± 7.80 (n=3)
#   Sparse Kappa: 2.57 ± 0.99 (n=10)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.91
#
# Starting simulations for mu = 0.25, P = 30
# Simulation 0 for mu=0.25, P=30: HMM_BAC = 0.622, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.25, P=30: HMM_BAC = 0.992, Jump_BAC = 0.992, SparseJump_BAC = 0.996, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.033
# Simulation 2 for mu=0.25, P=30: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 0.989, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.722
# Simulation 3 for mu=0.25, P=30: HMM_BAC = 0.713, Jump_BAC = 0.800, SparseJump_BAC = 0.555, Jump_Lambda = 5.878, Sparse_Lambda = 0.316, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.25, P=30: HMM_BAC = 0.992, Jump_BAC = 0.992, SparseJump_BAC = 0.996, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.378
# Simulation 5 for mu=0.25, P=30: HMM_BAC = 0.943, Jump_BAC = 0.999, SparseJump_BAC = 0.827, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 6 for mu=0.25, P=30: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.033
# Simulation 7 for mu=0.25, P=30: HMM_BAC = 0.931, Jump_BAC = 0.941, SparseJump_BAC = 0.941, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.689
# Simulation 8 for mu=0.25, P=30: HMM_BAC = 0.997, Jump_BAC = 0.997, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.755
# Simulation 9 for mu=0.25, P=30: HMM_BAC = 0.439, Jump_BAC = 0.870, SparseJump_BAC = 0.978, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 1.689
# Finished analysis for mu=0.25, P=30
#   HMM BAC = 0.863 ± 0.190
#   Jump BAC = 0.959 ± 0.066
#   Sparse Jump BAC = 0.928 ± 0.134
#   Jump Lambda: 6.61 ± 3.65 (n=3)
#   Sparse Lambda: 11.19 ± 7.40 (n=3)
#   Sparse Kappa: 1.93 ± 0.83 (n=6)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.694
#
# Starting simulations for mu = 0.25, P = 60
# Simulation 0 for mu=0.25, P=60: HMM_BAC = 0.586, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.25, P=60: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 0.989, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.076
# Simulation 2 for mu=0.25, P=60: HMM_BAC = 0.993, Jump_BAC = 0.999, SparseJump_BAC = 0.993, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.038
# Simulation 3 for mu=0.25, P=60: HMM_BAC = 0.285, Jump_BAC = 0.784, SparseJump_BAC = 0.699, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.25, P=60: HMM_BAC = 0.996, Jump_BAC = 0.996, SparseJump_BAC = 0.997, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.076
# Simulation 5 for mu=0.25, P=60: HMM_BAC = 0.483, Jump_BAC = 0.978, SparseJump_BAC = 1.000, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 3.076
# Simulation 6 for mu=0.25, P=60: HMM_BAC = 0.993, Jump_BAC = 0.993, SparseJump_BAC = 0.993, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.557
# Simulation 7 for mu=0.25, P=60: HMM_BAC = 0.563, Jump_BAC = 0.999, SparseJump_BAC = 0.999, Jump_Lambda = 5.878, Sparse_Lambda = 31.623, Sparse_Kappa = 2.038
# Simulation 8 for mu=0.25, P=60: HMM_BAC = 0.988, Jump_BAC = 0.998, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 31.623, Sparse_Kappa = 1.519
# Simulation 9 for mu=0.25, P=60: HMM_BAC = 0.491, Jump_BAC = 0.986, SparseJump_BAC = 0.562, Jump_Lambda = 17.013, Sparse_Lambda = 0.100, Sparse_Kappa = 1.000
# Finished analysis for mu=0.25, P=60
#   HMM BAC = 0.738 ± 0.267
#   Jump BAC = 0.973 ± 0.064
#   Sparse Jump BAC = 0.923 ± 0.150
#   Jump Lambda: 10.94 ± 13.28 (n=4)
#   Sparse Lambda: 15.50 ± 10.95 (n=3)
#   Sparse Kappa: 2.04 ± 0.84 (n=5)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.845
#
# Starting simulations for mu = 0.25, P = 150
# Simulation 0 for mu=0.25, P=150: HMM_BAC = 0.526, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 100.000, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.25, P=150: HMM_BAC = 0.799, Jump_BAC = 0.632, SparseJump_BAC = 0.624, Jump_Lambda = 0.084, Sparse_Lambda = 1.000, Sparse_Kappa = 2.730
# Simulation 2 for mu=0.25, P=150: HMM_BAC = 0.662, Jump_BAC = 0.984, SparseJump_BAC = 0.994, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 1.865
# Simulation 3 for mu=0.25, P=150: HMM_BAC = 0.711, Jump_BAC = 0.500, SparseJump_BAC = 0.836, Jump_Lambda = 142.510, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 4 for mu=0.25, P=150: HMM_BAC = 0.885, Jump_BAC = 0.995, SparseJump_BAC = 0.997, Jump_Lambda = 5.878, Sparse_Lambda = 31.623, Sparse_Kappa = 3.596
# Simulation 5 for mu=0.25, P=150: HMM_BAC = 0.431, Jump_BAC = 0.795, SparseJump_BAC = 0.970, Jump_Lambda = 49.239, Sparse_Lambda = 10.000, Sparse_Kappa = 4.461
# Simulation 6 for mu=0.25, P=150: HMM_BAC = 0.583, Jump_BAC = 0.879, SparseJump_BAC = 1.000, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 1.865
# Simulation 7 for mu=0.25, P=150: HMM_BAC = 0.481, Jump_BAC = 0.794, SparseJump_BAC = 0.853, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 8 for mu=0.25, P=150: HMM_BAC = 0.956, Jump_BAC = 0.998, SparseJump_BAC = 0.997, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 2.730
# Simulation 9 for mu=0.25, P=150: HMM_BAC = 0.672, Jump_BAC = 0.502, SparseJump_BAC = 0.574, Jump_Lambda = 0.084, Sparse_Lambda = 0.316, Sparse_Kappa = 1.865
# Finished analysis for mu=0.25, P=150
#   HMM BAC = 0.671 ± 0.164
#   Jump BAC = 0.808 ± 0.191
#   Sparse Jump BAC = 0.885 ± 0.155
#   Jump Lambda: 44.06 ± 51.92 (n=5)
#   Sparse Lambda: 30.11 ± 26.53 (n=5)
#   Sparse Kappa: 2.21 ± 1.11 (n=5)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.0142
#
# Starting simulations for mu = 0.25, P = 300
# Simulation 0 for mu=0.25, P=300: HMM_BAC = 0.598, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 100.000, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.25, P=300: HMM_BAC = 0.507, Jump_BAC = 0.737, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 31.623, Sparse_Kappa = 3.511
# Simulation 2 for mu=0.25, P=300: HMM_BAC = 0.594, Jump_BAC = 0.570, SparseJump_BAC = 0.989, Jump_Lambda = 0.084, Sparse_Lambda = 31.623, Sparse_Kappa = 2.255
# Simulation 3 for mu=0.25, P=300: HMM_BAC = 0.559, Jump_BAC = 0.824, SparseJump_BAC = 0.932, Jump_Lambda = 142.510, Sparse_Lambda = 10.000, Sparse_Kappa = 7.277
# Simulation 4 for mu=0.25, P=300: HMM_BAC = 0.620, Jump_BAC = 0.709, SparseJump_BAC = 0.989, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 8.533
# Simulation 5 for mu=0.25, P=300: HMM_BAC = 0.602, Jump_BAC = 0.784, SparseJump_BAC = 0.788, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 4.766
# Simulation 6 for mu=0.25, P=300: HMM_BAC = 0.591, Jump_BAC = 0.593, SparseJump_BAC = 1.000, Jump_Lambda = 2.031, Sparse_Lambda = 31.623, Sparse_Kappa = 2.255
# Simulation 7 for mu=0.25, P=300: HMM_BAC = 0.543, Jump_BAC = 0.972, SparseJump_BAC = 0.999, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 2.255
# Simulation 8 for mu=0.25, P=300: HMM_BAC = 0.615, Jump_BAC = 0.869, SparseJump_BAC = 1.000, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 2.255
# Simulation 9 for mu=0.25, P=300: HMM_BAC = 0.451, Jump_BAC = 0.758, SparseJump_BAC = 0.778, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 3.511
# Finished analysis for mu=0.25, P=300
#   HMM BAC = 0.568 ± 0.051
#   Jump BAC = 0.782 ± 0.135
#   Sparse Jump BAC = 0.947 ± 0.085
#   Jump Lambda: 49.20 ± 51.14 (n=5)
#   Sparse Lambda: 34.14 ± 23.55 (n=3)
#   Sparse Kappa: 3.76 ± 2.30 (n=6)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.00384
#
# Starting simulations for mu = 0.5, P = 15
# Simulation 0 for mu=0.5, P=15: HMM_BAC = 0.552, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.5, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 3.652
# Simulation 2 for mu=0.5, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 3.210
# Simulation 3 for mu=0.5, P=15: HMM_BAC = 0.998, Jump_BAC = 0.999, SparseJump_BAC = 0.999, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 2.768
# Simulation 4 for mu=0.5, P=15: HMM_BAC = 0.997, Jump_BAC = 0.997, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 1.221
# Simulation 5 for mu=0.5, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 2.326
# Simulation 6 for mu=0.5, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 3.210
# Simulation 7 for mu=0.5, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 2.547
# Simulation 8 for mu=0.5, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 2.105
# Simulation 9 for mu=0.5, P=15: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 3.162, Sparse_Kappa = 3.431
# Finished analysis for mu=0.5, P=15
#   HMM BAC = 0.955 ± 0.134
#   Jump BAC = 1.000 ± 0.001
#   Sparse Jump BAC = 1.000 ± 0.000
#   Jump Lambda: 9.44 ± 13.35 (n=3)
#   Sparse Lambda: 7.38 ± 8.52 (n=3)
#   Sparse Kappa: 2.55 ± 0.86 (n=9)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.159
#
# Starting simulations for mu = 0.5, P = 30
# Simulation 0 for mu=0.5, P=30: HMM_BAC = 0.622, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.5, P=30: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.755
# Simulation 2 for mu=0.5, P=30: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 3.411
# Simulation 3 for mu=0.5, P=30: HMM_BAC = 0.913, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.033
# Simulation 4 for mu=0.5, P=30: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 3.755
# Simulation 5 for mu=0.5, P=30: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 1.344
# Simulation 6 for mu=0.5, P=30: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 3.755
# Simulation 7 for mu=0.5, P=30: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.722
# Simulation 8 for mu=0.5, P=30: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.033
# Simulation 9 for mu=0.5, P=30: HMM_BAC = 0.997, Jump_BAC = 1.000, SparseJump_BAC = 0.999, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.378
# Finished analysis for mu=0.5, P=30
#   HMM BAC = 0.953 ± 0.113
#   Jump BAC = 1.000 ± 0.000
#   Sparse Jump BAC = 1.000 ± 0.000
#   Jump Lambda: 5.45 ± 4.26 (n=3)
#   Sparse Lambda: 10.11 ± 7.80 (n=3)
#   Sparse Kappa: 2.62 ± 0.97 (n=7)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.841
#
# Starting simulations for mu = 0.5, P = 60
# Simulation 0 for mu=0.5, P=60: HMM_BAC = 0.586, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 49.239, Sparse_Lambda = 31.623, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.5, P=60: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 2.031, Sparse_Lambda = 3.162, Sparse_Kappa = 4.114
# Simulation 2 for mu=0.5, P=60: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.595
# Simulation 3 for mu=0.5, P=60: HMM_BAC = 0.824, Jump_BAC = 0.949, SparseJump_BAC = 0.999, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 4.632
# Simulation 4 for mu=0.5, P=60: HMM_BAC = 0.997, Jump_BAC = 1.000, SparseJump_BAC = 0.997, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.038
# Simulation 5 for mu=0.5, P=60: HMM_BAC = 0.999, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.557
# Simulation 6 for mu=0.5, P=60: HMM_BAC = 0.993, Jump_BAC = 0.993, SparseJump_BAC = 0.993, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 2.557
# Simulation 7 for mu=0.5, P=60: HMM_BAC = 0.995, Jump_BAC = 0.999, SparseJump_BAC = 0.999, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 2.557
# Simulation 8 for mu=0.5, P=60: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.076
# Simulation 9 for mu=0.5, P=60: HMM_BAC = 0.705, Jump_BAC = 0.762, SparseJump_BAC = 1.000, Jump_Lambda = 0.702, Sparse_Lambda = 10.000, Sparse_Kappa = 4.114
# Finished analysis for mu=0.5, P=60
#   HMM BAC = 0.910 ± 0.144
#   Jump BAC = 0.970 ± 0.071
#   Sparse Jump BAC = 0.999 ± 0.002
#   Jump Lambda: 8.93 ± 13.58 (n=4)
#   Sparse Lambda: 11.48 ± 7.02 (n=3)
#   Sparse Kappa: 3.02 ± 1.05 (n=7)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.143
#
# Starting simulations for mu = 0.5, P = 150
# Simulation 0 for mu=0.5, P=150: HMM_BAC = 0.526, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 100.000, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.5, P=150: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.596
# Simulation 2 for mu=0.5, P=150: HMM_BAC = 0.991, Jump_BAC = 0.994, SparseJump_BAC = 0.994, Jump_Lambda = 5.878, Sparse_Lambda = 31.623, Sparse_Kappa = 1.865
# Simulation 3 for mu=0.5, P=150: HMM_BAC = 0.390, Jump_BAC = 0.797, SparseJump_BAC = 0.999, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 5.326
# Simulation 4 for mu=0.5, P=150: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 3.596
# Simulation 5 for mu=0.5, P=150: HMM_BAC = 0.913, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 4.461
# Simulation 6 for mu=0.5, P=150: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 2.730
# Simulation 7 for mu=0.5, P=150: HMM_BAC = 0.767, Jump_BAC = 0.989, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.596
# Simulation 8 for mu=0.5, P=150: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 2.031, Sparse_Lambda = 10.000, Sparse_Kappa = 3.596
# Simulation 9 for mu=0.5, P=150: HMM_BAC = 0.295, Jump_BAC = 0.998, SparseJump_BAC = 0.999, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 1.865
# Finished analysis for mu=0.5, P=150
#   HMM BAC = 0.788 ± 0.266
#   Jump BAC = 0.978 ± 0.060
#   Sparse Jump BAC = 0.999 ± 0.002
#   Jump Lambda: 20.61 ± 40.97 (n=4)
#   Sparse Lambda: 23.32 ± 26.94 (n=3)
#   Sparse Kappa: 3.16 ± 1.24 (n=6)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.0544
#
# Starting simulations for mu = 0.5, P = 300
# Simulation 0 for mu=0.5, P=300: HMM_BAC = 0.598, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 142.510, Sparse_Lambda = 100.000, Sparse_Kappa = 1.000
# Simulation 1 for mu=0.5, P=300: HMM_BAC = 0.999, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 3.511
# Simulation 2 for mu=0.5, P=300: HMM_BAC = 0.985, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 10.000, Sparse_Kappa = 4.766
# Simulation 3 for mu=0.5, P=300: HMM_BAC = 0.704, Jump_BAC = 0.991, SparseJump_BAC = 0.998, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 4.766
# Simulation 4 for mu=0.5, P=300: HMM_BAC = 0.996, Jump_BAC = 0.996, SparseJump_BAC = 0.997, Jump_Lambda = 5.878, Sparse_Lambda = 31.623, Sparse_Kappa = 2.255
# Simulation 5 for mu=0.5, P=300: HMM_BAC = 0.367, Jump_BAC = 0.996, SparseJump_BAC = 1.000, Jump_Lambda = 17.013, Sparse_Lambda = 10.000, Sparse_Kappa = 4.766
# Simulation 6 for mu=0.5, P=300: HMM_BAC = 0.987, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 31.623, Sparse_Kappa = 2.255
# Simulation 7 for mu=0.5, P=300: HMM_BAC = 0.633, Jump_BAC = 0.999, SparseJump_BAC = 0.999, Jump_Lambda = 17.013, Sparse_Lambda = 31.623, Sparse_Kappa = 3.511
# Simulation 8 for mu=0.5, P=300: HMM_BAC = 1.000, Jump_BAC = 1.000, SparseJump_BAC = 1.000, Jump_Lambda = 5.878, Sparse_Lambda = 31.623, Sparse_Kappa = 2.255
# Simulation 9 for mu=0.5, P=300: HMM_BAC = 0.574, Jump_BAC = 0.997, SparseJump_BAC = 0.698, Jump_Lambda = 142.510, Sparse_Lambda = 10.000, Sparse_Kappa = 4.766
# Finished analysis for mu=0.5, P=300
#   HMM BAC = 0.784 ± 0.224
#   Jump BAC = 0.998 ± 0.003
#   Sparse Jump BAC = 0.969 ± 0.090
#   Jump Lambda: 36.54 ± 53.20 (n=3)
#   Sparse Lambda: 27.65 ± 26.18 (n=3)
#   Sparse Kappa: 3.39 ± 1.31 (n=4)
#   p-value (Jump vs Sparse, Wilcoxon) = 0.358

# %%
# Convert summary results to a DataFrame and save to CSV
df_results = pd.DataFrame(final_rows)
print("\nFinal Summary Results:")
print(df_results, flush=True)
df_results.to_csv("simulation_results(no corr).csv", index=False)
# Out:
# Final Summary Results:
#       mu    P HMM (mean ± std) Jump (mean ± std) Sparse Jump (mean ± std) p-value (Jump vs Sparse, Wilcoxon) Jump Lambda (mean ± std, unique) Sparse Lambda (mean ± std, unique) Sparse Kappa (mean ± std, unique)
# 0   0.02   15      0.48 ± 0.09       0.67 ± 0.18              0.74 ± 0.16                             0.0549               6.22 ± 14.43 (n=6)                  7.96 ± 8.88 (n=5)                 1.24 ± 0.42 (n=4)
# 1   0.02   30      0.55 ± 0.08       0.66 ± 0.17              0.66 ± 0.15                              0.429                2.69 ± 5.07 (n=8)                  7.25 ± 8.97 (n=6)                 1.69 ± 1.09 (n=5)
# 2   0.02   60      0.51 ± 0.07       0.74 ± 0.19              0.75 ± 0.17                              0.297              17.97 ± 16.88 (n=4)                10.91 ± 10.77 (n=3)                 2.09 ± 1.00 (n=6)
# 3   0.02  150      0.56 ± 0.10       0.63 ± 0.15              0.66 ± 0.14                              0.339              34.13 ± 56.04 (n=5)                19.08 ± 29.29 (n=6)                 1.52 ± 0.88 (n=4)
# 4   0.02  300      0.53 ± 0.04       0.74 ± 0.14              0.73 ± 0.17                              0.779              61.20 ± 55.97 (n=5)                32.13 ± 35.91 (n=5)                 3.13 ± 1.95 (n=5)
# 5   0.05   15      0.48 ± 0.09       0.73 ± 0.16              0.72 ± 0.18                              0.571               7.44 ± 14.10 (n=5)                  7.47 ± 8.84 (n=5)                 1.27 ± 0.48 (n=4)
# 6   0.05   30      0.50 ± 0.08       0.71 ± 0.17              0.74 ± 0.18                              0.157                4.90 ± 6.42 (n=7)                  8.64 ± 8.74 (n=5)                 1.45 ± 0.82 (n=3)
# 7   0.05   60      0.52 ± 0.08       0.73 ± 0.18              0.70 ± 0.18                              0.661              15.87 ± 17.47 (n=5)                10.22 ± 11.02 (n=3)                 2.09 ± 0.91 (n=6)
# 8   0.05  150      0.55 ± 0.06       0.63 ± 0.15              0.65 ± 0.14                              0.297              48.26 ± 63.30 (n=6)                18.39 ± 29.58 (n=6)                 1.43 ± 0.58 (n=3)
# 9   0.05  300      0.51 ± 0.06       0.74 ± 0.14              0.73 ± 0.17                              0.524              48.58 ± 50.16 (n=5)                32.83 ± 35.40 (n=5)                 3.64 ± 2.13 (n=6)
# 10  0.10   15      0.56 ± 0.19       0.85 ± 0.15              0.82 ± 0.19                              0.876               8.75 ± 13.68 (n=5)                  8.69 ± 8.70 (n=5)                 1.66 ± 0.68 (n=7)
# 11  0.10   30      0.51 ± 0.13       0.80 ± 0.16              0.77 ± 0.19                               0.87                6.96 ± 6.82 (n=5)                  8.84 ± 8.60 (n=5)                 1.65 ± 0.86 (n=5)
# 12  0.10   60      0.51 ± 0.08       0.83 ± 0.17              0.84 ± 0.17                              0.524              13.19 ± 13.85 (n=6)                11.97 ± 10.43 (n=4)                 2.35 ± 1.04 (n=6)
# 13  0.10  150      0.52 ± 0.07       0.65 ± 0.16              0.67 ± 0.15                              0.288              53.04 ± 61.36 (n=6)                21.64 ± 29.07 (n=5)                 2.04 ± 1.38 (n=5)
# 14  0.10  300      0.52 ± 0.06       0.74 ± 0.15              0.74 ± 0.18                              0.524              36.06 ± 41.60 (n=5)                33.86 ± 35.55 (n=5)                 2.38 ± 1.53 (n=4)
# 15  0.25   15      0.88 ± 0.21       1.00 ± 0.00              1.00 ± 0.00                               0.91              10.21 ± 13.01 (n=2)                 10.11 ± 7.80 (n=3)                2.57 ± 0.99 (n=10)
# 16  0.25   30      0.86 ± 0.19       0.96 ± 0.07              0.93 ± 0.13                              0.694                6.61 ± 3.65 (n=3)                 11.19 ± 7.40 (n=3)                 1.93 ± 0.83 (n=6)
# 17  0.25   60      0.74 ± 0.27       0.97 ± 0.06              0.92 ± 0.15                              0.845              10.94 ± 13.28 (n=4)                15.50 ± 10.95 (n=3)                 2.04 ± 0.84 (n=5)
# 18  0.25  150      0.67 ± 0.16       0.81 ± 0.19          **0.88 ± 0.15**                             0.0142              44.06 ± 51.92 (n=5)                30.11 ± 26.53 (n=5)                 2.21 ± 1.11 (n=5)
# 19  0.25  300      0.57 ± 0.05       0.78 ± 0.13          **0.95 ± 0.08**                            0.00384              49.20 ± 51.14 (n=5)                34.14 ± 23.55 (n=3)                 3.76 ± 2.30 (n=6)
# 20  0.50   15      0.95 ± 0.13       1.00 ± 0.00              1.00 ± 0.00                              0.159               9.44 ± 13.35 (n=3)                  7.38 ± 8.52 (n=3)                 2.55 ± 0.86 (n=9)
# 21  0.50   30      0.95 ± 0.11       1.00 ± 0.00              1.00 ± 0.00                              0.841                5.45 ± 4.26 (n=3)                 10.11 ± 7.80 (n=3)                 2.62 ± 0.97 (n=7)
# 22  0.50   60      0.91 ± 0.14       0.97 ± 0.07              1.00 ± 0.00                              0.143               8.93 ± 13.58 (n=4)                 11.48 ± 7.02 (n=3)                 3.02 ± 1.05 (n=7)
# 23  0.50  150      0.79 ± 0.27       0.98 ± 0.06              1.00 ± 0.00                             0.0544              20.61 ± 40.97 (n=4)                23.32 ± 26.94 (n=3)                 3.16 ± 1.24 (n=6)
# 24  0.50  300      0.78 ± 0.22       1.00 ± 0.00              0.97 ± 0.09                              0.358              36.54 ± 53.20 (n=3)                27.65 ± 26.18 (n=3)                 3.39 ± 1.31 (n=4)

# %%
# Convert raw simulation details to a DataFrame and save to CSV for full transparency
df_sim_details = pd.DataFrame(simulation_details)
print("\nRaw Simulation Details (first few rows):")
print(df_sim_details.head(), flush=True)
df_sim_details.to_csv("simulation_simulation_details(no corr).csv", index=False)
# Out:
# Raw Simulation Details (first few rows):
#      mu   P  sim   HMM_BAC  Jump_BAC  SparseJump_BAC  Jump_Lambda  Sparse_Lambda  Sparse_Kappa
# 0  0.02  15    0  0.552000  1.000000        1.000000    49.238826      31.622777      1.000000
# 1  0.02  15    1  0.563331  0.512708        0.546932     0.010000       0.316228      1.000000
# 2  0.02  15    2  0.437398  0.517886        0.830488     0.242446      10.000000      2.325992
# 3  0.02  15    3  0.417347  0.541837        0.664286     0.701704       3.162278      1.000000
# 4  0.02  15    4  0.453025  0.566300        0.745875     0.701704      10.000000      1.662996
